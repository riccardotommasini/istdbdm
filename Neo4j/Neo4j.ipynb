# %% [markdown]
# # Introduction:
# ### Neo4J:
#    <a href="https://neo4j.com/">Neo4J</a>  is a graph database management system developed by Neo4j, Inc. Described by its developers as a native graph storage and processing. It is the most popular graph database according to DB-Engines ranking, and the 22nd most popular database overall.<br/>
# <img src="https://neo4j.com/wp-content/themes/neo4jweb/assets/images/neo4j-logo-2015.png">
#
#
# ### The Property Graph Model
# * In the property graph model, data is organized as nodes, relationships, and properties (data stored on the nodes or relationships).
#
# <img src= 'https://dist.neo4j.com/wp-content/uploads/property_graph_elements.jpg' width='600'>

# %% [markdown]
# ###  Cypher Query Language
#
# Cypher is Neo4j’s graph query language that allows users to store and retrieve data from the graph database. Cypher’s syntax provides a visual and logical way to match patterns of nodes and relationships in the graph.
# t is a declarative, SQL-inspired language for describing visual patterns in graphs using ASCII-Art syntax. It allows us to state what we want to select, insert, update, or delete from our graph data without a description of exactly how to do it.
#
# - First Steps with Cypher can be followed from this <a href='https://neo4j.com/developer/cypher/'>link </a>.

# %% [markdown]
# ## Pre-Lab:
# ### Installation
#
# 1. Install neo4j 3.5 Community Edition followin this <a href='https://neo4j.com/download-thanks/?edition=community&release=3.5.21&flavour=winzip&_ga=2.186751336.1137015944.1598288824-1813280835.1541597058'>link </a>
#
#
# Note:
#
#  * Click  <a href= 'https://neo4j.com/download-thanks-desktop/?edition=desktop&flavour=winstall64&release=1.3.4&offline=true'> here </a> to download the latest version of neo4j DeskTop for Windows.
#  * Follow the installation guide provided <a href= 'https://neo4j.com/download-thanks-desktop/?edition=desktop&flavour=winstall64&release=1.3.4&offline=true#installation-guide' > here </a> to download, install neo4j DEsktop on your Windows.
#  * make sure that you run Neo4j as a console application, use:
#      - <b> NEO4J_HOME\bin\neo4j console </b>
#      - Or install Neo4j as a service using: <b>NEO4J_HOME\bin\neo4j install-service </b>

# %% [markdown]
# ## Task 1: Convert a RDB to a Graph DB
# In this task, you are going to:
# - Watch a Video explaining the advtanges of Graph Databases over RDBMS
# - Remodel a toy RDB into a Graph DB.
# - Create the a graph of the toy database using Cyper Language

# %% [markdown]
# #### Watch the following video and mention some of the advantages of using Graph Databases over RDBMS

# %%
# %%HTML
# <center><iframe width="560" height="315" src="https://www.youtube.com/embed/NO3C-CWykkY" frameborder="0" allowfullscreen></iframe>
# Out:
# <center><iframe width="560" height="315" src="https://www.youtube.com/embed/NO3C-CWykkY" frameborder="0" allowfullscreen></iframe>

# %% [markdown]
# <font color = "Red"><b>Advantages of Using Neo4J over RDBMS:</b></font>
# <br>1.
# <br>2.
# <br>3.

# %% [markdown]
# #### Given the following toy relational database, Convert this toy database into a Graph database using any drawing software.

# %% [markdown]
# <img src="RDBSchema.png" alt="3" border="0">

# %%
#### YOUR IMAGE of The Property Graph Schema HERE

# %% [markdown]
# <img src="GDBSchema.JPG" alt="3" border="0">

# %% [markdown]
# #### 1) Use Cypher Query Language to create the above Graph toy database, you have just drawed

# %% [markdown]
# ### py2neo
#
# py2neo is one of Neo4j's Python drivers. It offers a fully-featured interface for interacting with your data in Neo4j. Install py2neo with pip install py2neo.

# %% [markdown]
# ### Connect
#
# Connect to Neo4j with the Graph class.

# %%
from py2neo import Graph
try:
    graph = Graph(auth=("neo4j", "engmohamed"))
except:
    print("Error Connection to Neo4j DB!!")

# %%
graph.delete_all()

# %% [markdown]
# ### Nodes
#
# Create nodes with the Node class. The first argument is the node's label. The remaining arguments are an arbitrary amount of node properties or key-value pairs.

# %%
from py2neo import Node

#Person_Nodes
charlSheen = Node("Person", id=1, name="Charlie Sheen")
MichDouglas = Node("Person", id=2, name="Micheal Douglas")
martSheen = Node("Person", id=3, name="Martin Sheen")
morgan = Node("Person", id=4, name="Morgan Freeman")

#Movie_Nodes

wallst = Node("Movie", id=1, title="Wall Street", year=1987)
americanPres = Node("Movie",id=2, title="The American President", year=1995)
shawshank = Node("Movie",id=3, title="The Shawshank Redemption", year=1994)

#Country_Nodes
usa = Node("Country", name="USA")


graph.create(charlSheen | MichDouglas | martSheen | morgan | wallst | americanPres | shawshank | usa)

# %% [markdown]
# #### Check created nodes in the graph using Cypher query

# %%
query = """ MATCH (n)RETURN n"""
allNodes = graph.run(query)
for node in allNodes:
    print(node)
# Out:
# Node('Person', id=3, name='Martin Sheen')
# Node('Person', id=4, name='Morgan Freeman')
# Node('Person', id=1, name='Charlie Sheen')
# Node('Person', id=2, name='Micheal Douglas')
# Node('Country', name='USA')
# Node('Movie', id=3, title='The Shawshank Redemption', year=1994)
# Node('Movie', id=1, title='Wall Street', year=1987)
# Node('Movie', id=2, title='The American President', year=1995)

# %% [markdown]
# ### Relationships
#
# Create relationships between nodes with the Relationship class.

# %%
from py2neo import Relationship

#MADE_IN RelationShips
graph.create(Relationship(wallst, "MADE_IN", usa))
graph.create(Relationship(americanPres, "MADE_IN", usa))
graph.create(Relationship(shawshank, "MADE_IN", usa))

#PLAYED Relationships
graph.create(Relationship(charlSheen, "PLAYED", wallst, role=["Bud Fox"]))
graph.create(Relationship(martSheen, "PLAYED", wallst, role=["Carl Fox"]))
graph.create(Relationship(MichDouglas, "PLAYED", wallst, role=["Gordon Gekko"]))

graph.create(Relationship(martSheen, "PLAYED", americanPres, role=["A.J. MacInerney"]))
graph.create(Relationship(MichDouglas, "PLAYED", americanPres, role=["President Andrew Shepherd"]))

graph.create(Relationship(morgan, "PLAYED", shawshank, role=["Ellis Boyd 'Red' Redding"]))

# %% [markdown]
# ### Get Hands On "CRUD" Operations with Cypher Query Language!!

# %% [markdown]
# ### Extend you "Movies" Knowledge Graph (The power of Graph DBs!!)
#
# Imagine now that we are going to extend our graph DB with new movies, actors, even with new directors.
#
# - We add <b>"The matrix"</b> movie which was released in <b>(1999)</b>, and has a new property "Tagline" <b>("Welcome to the Real World")</b>.
# - We also add 4 new actors (Person):
#     - "Keanu Reeves" who was born in (1964). Note "born" property is also new.
#     - "Carrie-Anne Moss" who was born in (1967).
#     - "Laurence Fishburne" who was born in (1960).
#     - "Hugo Weaving" who was born in (1960).
# - Moreover, we add 3 directors (Person) :
#     - 'Lilly Wachowski', born in (1967)
#     - 'Lana Wachowski', born in(1965)
#     - 'Joel Silver', born in (1952)
# - For these directors specify one more Label ("Director").
# - We Create a new <b>RelationType "DIRECTED" </b> that goes from the later 3 director nodes to "the Matrix" movie node.

# %%
creMoviequery ="""
MERGE (TheMatrix:Movie {id:4, title:'The Matrix', year:1999, tagline:'Welcome to the Real World'})
RETURN TheMatrix
"""
data = graph.run(creMoviequery)
for d in data:
    print(d)
# Out:
# Node('Movie', id=4, tagline='Welcome to the Real World', title='The Matrix', year=1999)

# %%
creActorsquery ="""
MERGE (Keanu:Person {id:5, name:'Keanu Reeves', born:1964})
MERGE (Carrie:Person {id:6, name:'Carrie-Anne Moss', born:1967})
MERGE (Laurence:Person {id:7,name:'Laurence Fishburne', born:1961})
MERGE (Hugo:Person {id:8,name:'Hugo Weaving', born:1960})

RETURN Keanu, Carrie, Laurence, Hugo
"""
data = graph.run(creActorsquery)
for d in data:
    print(d)
# Out:
# Node('Person', born=1964, id=5, name='Keanu Reeves')	Node('Person', born=1967, id=6, name='Carrie-Anne Moss')	Node('Person', born=1961, id=7, name='Laurence Fishburne')	Node('Person', born=1960, id=8, name='Hugo Weaving')

# %%
creDirectorsquery ="""
MERGE (LillyW:Person:Director {id:9,name:'Lilly Wachowski', born:1967})
MERGE (LanaW:Person:Director {id:10,name:'Lana Wachowski', born:1965})

RETURN LillyW, LanaW
"""
data = graph.run(creDirectorsquery)
for d in data:
    print(d)
# Out:
# Node('Director', 'Person', born=1967, id=9, name='Lilly Wachowski')	Node('Director', 'Person', born=1965, id=10, name='Lana Wachowski')

# %%
creRELSquery ="""
MERGE r1=(Keanu:Person{name:'Keanu Reeves'})-[:PLAYED {role:['Neo']}]->(TheMatrix:Movie {title:'The Matrix'})
MERGE r2=(Carrie:Person {name:'Carrie-Anne Moss'})-[:PLAYED {role:['Trinity']}]->(TheMatrix)
MERGE r3=(Laurence:Person {name:'Laurence Fishburne'})-[:PLAYED {role:['Morpheus']}]->(TheMatrix)
MERGE r4=(Hugo:Person {name:'Hugo Weaving'})-[:PLAYED {role:['Agent Smith']}]->(TheMatrix)

MERGE r5=(LillyW:Person:Director {name:'Lilly Wachowski'})-[:DIRECTED]->(TheMatrix)
MERGE r6=(LanaW:Person:Director {name:'Lana Wachowski'})-[:DIRECTED]->(TheMatrix)

RETURN r1, r2, r3, r4, r5, r6
"""
data = graph.run(creRELSquery)
for d in data:
    print(d, "\n")
# Out:
# Path(Node('Person', name='Keanu Reeves'), PLAYED(Node('Person', name='Keanu Reeves'), Node('Movie', title='The Matrix'), role=['Neo']))	Path(Node('Person', name='Carrie-Anne Moss'), PLAYED(Node('Person', name='Carrie-Anne Moss'), Node('Movie', title='The Matrix'), role=['Trinity']))	Path(Node('Person', name='Laurence Fishburne'), PLAYED(Node('Person', name='Laurence Fishburne'), Node('Movie', title='The Matrix'), role=['Morpheus']))	Path(Node('Person', name='Hugo Weaving'), PLAYED(Node('Person', name='Hugo Weaving'), Node('Movie', title='The Matrix'), role=['Agent Smith']))	Path(Node('Director', 'Person', name='Lilly Wachowski'), DIRECTED(Node('Director', 'Person', name='Lilly Wachowski'), Node('Movie', title='The Matrix')))	Path(Node('Director', 'Person', name='Lana Wachowski'), DIRECTED(Node('Director', 'Person', name='Lana Wachowski'), Node('Movie', title='The Matrix')))

# %% [markdown]
# #### OR just Run This in the neo4j Web-browser as a full Cypher query!
#
# ```
# MERGE (TheMatrix:Movie {id:4, title:'The Matrix', year:1999, tagline:'Welcome to the Real World'})
#
# MERGE (Keanu:Person {id:5, name:'Keanu Reeves', born:1964})
# MERGE (Carrie:Person {id:6, name:'Carrie-Anne Moss', born:1967})
# MERGE (Laurence:Person {id:7,name:'Laurence Fishburne', born:1961})
# MERGE (Hugo:Person {id:8,name:'Hugo Weaving', born:1960})
#
# MERGE (LillyW:Person:Director {id:9,name:'Lilly Wachowski', born:1967})
# MERGE (LanaW:Person:Director {id:10,name:'Lana Wachowski', born:1965})
#
#
# MERGE (Keanu)-[:PLAYED {role:['Neo']}]->(TheMatrix)
# MERGE (Carrie)-[:PLAYED {role:['Trinity']}]->(TheMatrix)
# MERGE (Laurence)-[:PLAYED {role:['Morpheus']}]->(TheMatrix)
# MERGE (Hugo)-[:PLAYED {role:['Agent Smith']}]->(TheMatrix)
#
# MERGE (LillyW)-[:DIRECTED]->(TheMatrix)
# MERGE (LanaW)-[:DIRECTED]->(TheMatrix)
#
# ```

# %% [markdown]
# #### After Running Such new Insertions to The Graph it will look like That

# %% [markdown]
# <center> <img src="moviesGraph.JPG" alt="3" border="0">

# %% [markdown]
# # Querying our Data

# %% [markdown]
# #### Get all the Person Nodes in the GDB

# %%
query = """
MATCH (p:Person)
RETURN p
"""
personNodes = graph.run(query)
for person in personNodes:
    print(person)
# Out:
# Node('Person', name='Keanu Reeves')
# Node('Person', name='Carrie-Anne Moss')
# Node('Person', name='Laurence Fishburne')
# Node('Person', name='Hugo Weaving')
# Node('Director', 'Person', name='Lilly Wachowski')
# Node('Director', 'Person', name='Lana Wachowski')
# Node('Person', born=1964, id=5, name='Keanu Reeves')
# Node('Person', born=1967, id=6, name='Carrie-Anne Moss')
# Node('Person', born=1961, id=7, name='Laurence Fishburne')
# Node('Person', born=1960, id=8, name='Hugo Weaving')
# Node('Person', id=3, name='Martin Sheen')
# Node('Person', id=4, name='Morgan Freeman')
# Node('Person', id=1, name='Charlie Sheen')
# Node('Person', id=2, name='Micheal Douglas')
# Node('Director', 'Person', born=1967, id=9, name='Lilly Wachowski')
# Node('Director', 'Person', born=1965, id=10, name='Lana Wachowski')

# %% [markdown]
# ### Sorting the Results
#
# #### Get All Movies from the Previous Graph, sorted from recent to old

# %%
query = """
MATCH (mov:Movie)
RETURN mov.title AS Movie, mov.year AS Released_IN 
ORDER BY Released_IN DESC
"""
data = graph.run(query)
for d in data:
    print(d)
# Out:
# 'The American President'	1995
# 'The Shawshank Redemption'	1994
# 'Wall Street'	1987

# %% [markdown]
# ### Filtering the Results
#
# #### Get All Movies released in the <b>90s</b> (after year (1990) and before 2000) ordered from old to recent.

# %%
query = """
MATCH (mov:Movie)
WHERE mov.year > 1990 
RETURN mov.title AS Movie, mov.year AS Released_IN
ORDER BY Released_IN DESC
"""
data = graph.run(query)
for d in data:
    print(d)
# Out:
# 'The American President'	1995
# 'The Shawshank Redemption'	1994

# %% [markdown]
# #### Get Movies and Actors from the Previous Graph

# %%
query = """
MATCH (person:Person)-[:PLAYED]->(mov:Movie)
RETURN person.name AS Actor, mov.title AS Movie
"""
data = graph.run(query)
for d in data:
    print(d)
# Out:
# 'Micheal Douglas'	'Wall Street'
# 'Martin Sheen'	'Wall Street'
# 'Charlie Sheen'	'Wall Street'
# 'Morgan Freeman'	'The Shawshank Redemption'
# 'Micheal Douglas'	'The American President'
# 'Martin Sheen'	'The American President'
# 'Hugo Weaving'	'The Matrix'
# 'Laurence Fishburne'	'The Matrix'
# 'Carrie-Anne Moss'	'The Matrix'
# 'Keanu Reeves'	'The Matrix'

# %% [markdown]
# #### Get count of "Movies" in your graphDB

# %%
query = """
MATCH (mov:Movie)
RETURN count(mov) AS Count_Movies
"""
data = graph.run(query)
for d in data:
    print("Count= ",d)
# Out:
# Count=  4

# %% [markdown]
# #### In this graph, for every "Actor" get the number of movies he played

# %%
query = """
MATCH (actor:Person)-[:PLAYED]->(mov:Movie)
RETURN actor.name as Actor, count(mov) AS Count_Movies
"""
data = graph.run(query)
for d in data:
    print(d)
# Out:
# 'Micheal Douglas'	2
# 'Martin Sheen'	2
# 'Charlie Sheen'	1
# 'Morgan Freeman'	1
# 'Keanu Reeves'	1
# 'Hugo Weaving'	1
# 'Carrie-Anne Moss'	1
# 'Laurence Fishburne'	1

# %% [markdown]
# #### In this graph, List the movies that every Actor Played
# <b>Hint:</b> use the aggregation function <b>"COLLECT"</b> to group movies as a list.

# %%
query = """
MATCH (actor:Person)-[:PLAYED]->(mov:Movie)
RETURN actor.name as Actor, COLLECT(mov.title) AS Played_Movies
"""
data = graph.run(query)
for d in data:
    print(d)
# Out:
# 'Micheal Douglas'	['Wall Street', 'The American President']
# 'Martin Sheen'	['Wall Street', 'The American President']
# 'Charlie Sheen'	['Wall Street']
# 'Morgan Freeman'	['The Shawshank Redemption']
# 'Keanu Reeves'	['The Matrix']
# 'Hugo Weaving'	['The Matrix']
# 'Carrie-Anne Moss'	['The Matrix']
# 'Laurence Fishburne'	['The Matrix']

# %% [markdown]
# ####  Get List of Directors From the graph

# %%
query = """
MATCH (direct:Director)
RETURN direct.name as Director
"""
data = graph.run(query)
print("Directors: ")
for d in data:
    print(d)
# Out:
# Directors:
# 'Lilly Wachowski'
# 'Lana Wachowski'

# %% [markdown]
# #### UPDATE Graph elements (Nodes or Relationships) Data with Cypher

# %%
print("The Matrix before updte: ")

query = """
MATCH (mov:Movie{title:'The Matrix'})
RETURN mov
"""
data = graph.run(query)
for d in data:
    print(d,"\n")


query = """
MATCH (mov:Movie{title:'The Matrix'})
SET mov.year=2001
RETURN mov
"""
data = graph.run(query)
print("The matrix Updated: ")
for d in data:
    print(d)
# Out:
# The Matrix before updte:
# Node('Movie', id=4, tagline='Welcome to the Real World', title='The Matrix', year=2001)
#
# The matrix Updated:
# Node('Movie', id=4, tagline='Welcome to the Real World', title='The Matrix', year=2001)

# %% [markdown]
# ### DELTE From Graph elements (Nodes or Relationships), and Removing Properities with Cypher
#
# * The <b>REMOVE</b> clause is used to remove properties from nodes and relationships, and to remove labels from nodes.
#
# * While the <b> DELETE </b> clause is used to delete nodes, relationships or paths.

# %% [markdown]
# #### Remove the ```tagLine``` from the ```Movie``` Node
#
# - Notice Movie "The Matrix" before and after!

# %%
query = """
MATCH (mov:Movie)
REMOVE mov.tagline
RETURN mov
"""
data = graph.run(query)
for d in data:
    print(d)
# Out:
# Node('Movie', title='The Matrix', year=2001)
# Node('Movie', id=4, title='The Matrix', year=2001)
# Node('Movie', id=3, title='The Shawshank Redemption', year=2001)
# Node('Movie', id=1, title='Wall Street', year=2001)
# Node('Movie', id=2, title='The American President', year=2001)

# %% [markdown]
# #### Remove the ```Director``` from Person Nodes with that label
#
# * Notice all Persons (Some of them have the "Director" Label)

# %%
query = """
MATCH (p:Person)
RETURN p
"""
personNodes = graph.run(query)
for person in personNodes:
    print(person)
# Out:
# Node('Person', name='Keanu Reeves')
# Node('Person', name='Carrie-Anne Moss')
# Node('Person', name='Laurence Fishburne')
# Node('Person', name='Hugo Weaving')
# Node('Director', 'Person', name='Lilly Wachowski')
# Node('Director', 'Person', name='Lana Wachowski')
# Node('Person', born=1964, id=5, name='Keanu Reeves')
# Node('Person', born=1967, id=6, name='Carrie-Anne Moss')
# Node('Person', born=1961, id=7, name='Laurence Fishburne')
# Node('Person', born=1960, id=8, name='Hugo Weaving')
# Node('Person', id=3, name='Martin Sheen')
# Node('Person', id=4, name='Morgan Freeman')
# Node('Person', id=1, name='Charlie Sheen')
# Node('Person', id=2, name='Micheal Douglas')
# Node('Director', 'Person', born=1967, id=9, name='Lilly Wachowski')
# Node('Director', 'Person', born=1965, id=10, name='Lana Wachowski')

# %%
query= """
MATCH (p:Person)
REMOVE p:Director
RETURN p
"""
personNodes = graph.run(query)
for person in personNodes:
    print(person)
# Out:
# Node('Person', name='Keanu Reeves')
# Node('Person', name='Carrie-Anne Moss')
# Node('Person', name='Laurence Fishburne')
# Node('Person', name='Hugo Weaving')
# Node('Person', name='Lilly Wachowski')
# Node('Person', name='Lana Wachowski')
# Node('Person', born=1964, id=5, name='Keanu Reeves')
# Node('Person', born=1967, id=6, name='Carrie-Anne Moss')
# Node('Person', born=1961, id=7, name='Laurence Fishburne')
# Node('Person', born=1960, id=8, name='Hugo Weaving')
# Node('Person', id=3, name='Martin Sheen')
# Node('Person', id=4, name='Morgan Freeman')
# Node('Person', id=1, name='Charlie Sheen')
# Node('Person', id=2, name='Micheal Douglas')
# Node('Person', born=1967, id=9, name='Lilly Wachowski')
# Node('Person', born=1965, id=10, name='Lana Wachowski')

# %% [markdown]
# #### Delete "Agent Smith", the Actor with the name <b>"Hugo Weaving"</b>  as he is the bad guy here :)

# %%
query= """
MATCH (p:Person{name:'Hugo Weaving'})
RETURN p
"""
personNodes = graph.run(query)
for person in personNodes:
    print(person)

# %%
query= """
MATCH (p:Person{name:'Hugo Weaving'})
DETACH DELETE p
RETURN p
"""
personNodes = graph.run(query)
for person in personNodes:
    print(person)
# Out:
# Node()

# %% [markdown]
# ### Excercise:
#
# Given the attched 3 CSV files (movies.csv, persons.csv, roles.csv):
#
# - open the neo4j web browser (http://localhost:7474/browser/)
# - and use the <b> <a href ='https://neo4j.com/docs/cypher-manual/current/clauses/load-csv/#:~:text=To%20import%20data%20from%20a,csv.'>LOAD CSV</a> </b> utility of Neo4j to import data from CSV files into a neo4j as a property graph.
#
# * Notes:
#     - Drop your files in the neo4jHome/import directory
#     - Follow this tutourial to understand the process better (https://neo4j.com/developer/desktop-csv-import/)
# - Syntax of Load will be something like that:
# ```
# LOAD CSV WITH HEADERS FROM "file:///persons.csv" AS csvLine ....
# ```

# %% [markdown]
# 2. We can use the <b> "Neo4j Python" </b> driver which is officially supported by Neo4j and connects to the database using the binary protocol.
# It aims to be minimal, while being idiomatic to Python. <a href="https://neo4j.com/developer/python/">here</a>:
# ```
# pip install neo4j
# ```

# %%
# !pip install neo4j
# Out:
# Requirement already satisfied: neo4j in c:\programdata\anaconda3\lib\site-packages (4.1.0)
# Requirement already satisfied: pytz in c:\programdata\anaconda3\lib\site-packages (from neo4j) (2019.1)

# %%
from neo4j import __version__ as neo4j_version
print(neo4j_version)
# Out:
# 4.1.0

# %%
# import the neo4j driver for Python
from neo4j import GraphDatabase

# %%
# Database Credentials
uri = "bolt://localhost:7687"

# Default Credentials on the VM
userName = "neo4j" #YOUR CODE HERE
password = "engmohamed" 

# Connect to the neo4j database server
graphDB_Driver = GraphDatabase.driver(uri, auth=(userName, password))

# %%
# import the neo4j driver for Python
from neo4j import GraphDatabase

class Neo4jConnection:
    
    def __init__(self, uri, user, pwd):
        self.__uri = uri
        self.__user = user
        self.__pwd = pwd
        self.__driver = None
        try:
            self.__driver = GraphDatabase.driver(self.__uri, auth=(self.__user, self.__pwd))
        except Exception as e:
            print("Failed to create the driver:", e)
        
    def close(self):
        if self.__driver is not None:
            self.__driver.close()
        
    def query(self, query, db=None):
        assert self.__driver is not None, "Driver not initialized!"
        session = None
        response = None
        try: 
            session = self.__driver.session(database=db) if db is not None else self.__driver.session() 
            response = list(session.run(query))
        except Exception as e:
            print("Query failed:", e)
        finally: 
            if session is not None:
                session.close()
        return response

# %%
conn = Neo4jConnection(uri="bolt://localhost:7687", user="neo4j", pwd="engmohamed")

# %% [markdown]
# ## Task 2: Perform some queries on the Graph database using Cypher Query Language.
# In this task, you are going to:
# - Import movielens graph database into neo4j
# - Perform Several Cypher quereis on this database

# %% [markdown]
# ##### The movielens Dataset
#
# The dataset that we are using consists of data obtained from MovieLens 1, a recommender system whose users give movies a rate between 1 and 5 based on whether they dislike or love them. MovieLens uses the rates to recommend movies that its users might like. The dataset is modeled as a directed graph and consists of 100,004 rates on 9,125 movies across 671 users between January 9th, 1995 and October 16, 2016. The dataset also contains the names of the directors and the actors of each movie. A directed graph G = (V , E ) consists of:
#
#     A set V of nodes corresponding to the entities, such as movies, users, actors and direc- tors.
#     A set E of links, each connecting two nodes and representing a relationship between two entities. For instance, a link between a director and a movie represents the rela- tionship “directed by”.
#
#
# ### mvielens.db
# ##### 1- Please, copy the attached 'mvielens.db' graph DB file to your neo4jhome/data/databases/
# ##### 2- change the active DB from the neo4j configuration to the mvielens.db, by default it is graph.db by edititng the file neo4jhome/conf/neo4j.conf and change graph.db to mvielens.db in the line dbms.active_database=graph.db (after removing the '#' from the begininnig of the file)
# ##### 3- Don't forget to restart neo4j server (neo4jhome/bin/neo4j restart).
#
# ##### 4- In the following subtasks, Write the Cypher Query which will perform each of the following tasks

# %% [markdown]
# #### Simplified Schema with labels of DB:

# %% [markdown]
# <img src="movielensschema.JPG" alt="3" border="0">

# %% [markdown]
# #### 1. The genres of the movies in the database.

# %%
cqlEdgeQuery = 'MATCH (g:Genre) return Distinct g'

with graphDB_Driver.session() as graphDB_Session:
    nodes = graphDB_Session.run(cqlEdgeQuery)
    for node in nodes:
        print(node)
# Out:
# <Record g=<Node id=20777 labels=frozenset({'Genre'}) properties={'name': 'romance'}>>
# <Record g=<Node id=20778 labels=frozenset({'Genre'}) properties={'name': 'fantasy'}>>
# <Record g=<Node id=20779 labels=frozenset({'Genre'}) properties={'name': 'horror'}>>
# <Record g=<Node id=20780 labels=frozenset({'Genre'}) properties={'name': 'musical'}>>
# <Record g=<Node id=20781 labels=frozenset({'Genre'}) properties={'name': 'comedy'}>>
# <Record g=<Node id=20782 labels=frozenset({'Genre'}) properties={'name': 'war'}>>
# <Record g=<Node id=20783 labels=frozenset({'Genre'}) properties={'name': 'imax'}>>
# <Record g=<Node id=20784 labels=frozenset({'Genre'}) properties={'name': 'thriller'}>>
# <Record g=<Node id=20785 labels=frozenset({'Genre'}) properties={'name': 'animation'}>>
# <Record g=<Node id=20786 labels=frozenset({'Genre'}) properties={'name': 'adventure'}>>
# <Record g=<Node id=20787 labels=frozenset({'Genre'}) properties={'name': 'drama'}>>
# <Record g=<Node id=20788 labels=frozenset({'Genre'}) properties={'name': 'mystery'}>>
# <Record g=<Node id=20789 labels=frozenset({'Genre'}) properties={'name': 'children'}>>
# <Record g=<Node id=20790 labels=frozenset({'Genre'}) properties={'name': 'sci-fi'}>>
# <Record g=<Node id=20791 labels=frozenset({'Genre'}) properties={'name': 'action'}>>
# <Record g=<Node id=20792 labels=frozenset({'Genre'}) properties={'name': 'crime'}>>
# <Record g=<Node id=20793 labels=frozenset({'Genre'}) properties={'name': 'western'}>>
# <Record g=<Node id=20794 labels=frozenset({'Genre'}) properties={'name': 'film-noir'}>>
# <Record g=<Node id=20795 labels=frozenset({'Genre'}) properties={'name': 'documentary'}>>

# %% [markdown]
# ### ipython-cypher
# [ipython-cypher](https://github.com/versae/ipython-cypher) is another way to connect to a graph database in python. it uses <b> neo4jrestclient_ driver </b>, then issue Cypher commands within IPython or IPython Notebook.
# #### ipython-cypher install

# %%
! pip install ipython-cypher

# %% [markdown]
# #### Inside IPython, load the extension:

# %%
# %load_ext cypher
# Out:
# The cypher extension is already loaded. To reload it, use:
#   %reload_ext cypher

# %% [markdown]
# #### And then you are reay to go by using the <b>%cypher</b> or <b>%%cypher</b> line magic:
#
# you have to write down the connection url http://username:password@127.0.0.1:7474/db/data after the %%cypher to access your active DB using the neo4j http port (7474)

# %% [markdown]
# - '''%cypher''' is intended for one-line Cypher queries and '''%%cypher''' is intended for multi-line Cypher queries.
# - Placing "%%cypher" above a Cypher query will display that query's results.

# %%
# %cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data   MATCH (g:Genre) RETURN Distinct g.name AS genre
# Out:
# 19 rows affected.
# [['romance'],
#  ['fantasy'],
#  ['horror'],
#  ['musical'],
#  ['comedy'],
#  ['war'],
#  ['imax'],
#  ['thriller'],
#  ['animation'],
#  ['adventure'],
#  ['drama'],
#  ['mystery'],
#  ['children'],
#  ['sci-fi'],
#  ['action'],
#  ['crime'],
#  ['western'],
#  ['film-noir'],
#  ['documentary']]

# %% [markdown]
# #### 2. Get the number of movies in the database.

# %%
# %cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data   MATCH (m:Movie) RETURN COUNT(m) AS count
# Out:
# 1 rows affected.
# [[9125]]

# %% [markdown]
# #### 3. The title of the movies released in 2005.

# %%
# %%cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH (m:Movie)
# WHERE m.year ='2005'
# RETURN m.title AS movieTitle
# Out:
# 233 rows affected.
# [['Street Fight'],
#  ['Shooting Dogs'],
#  ["The Hitchhiker's Guide to the Galaxy"],
#  ['The Amityville Horror'],
#  ['A Lot Like Love'],
#  ['Enron: The Smartest Guys in the Room'],
#  ['xXx: State of the Union'],
#  ['Kingdom of Heaven'],
#  ['House of Wax'],
#  ['Unleashed'],
#  ['Zerophilia'],
#  ['Star Wars: Episode III - Revenge of the Sith'],
#  ['Kicking & Screaming'],
#  ['Monster-in-Law'],
#  ['Madagascar'],
#  ['Mad Hot Ballroom'],
#  ['The Longest Yard'],
#  ['Cinderella Man'],
#  ['The Sisterhood of the Traveling Pants'],
#  ['Lords of Dogtown'],
#  ['Mr. & Mrs. Smith'],
#  ['The Adventures of Sharkboy and Lavagirl 3-D'],
#  ['Parineeta'],
#  ['Batman Begins'],
#  ['Herbie: Fully Loaded'],
#  ['Land of the Dead'],
#  ['Bewitched'],
#  ['Rize'],
#  ['Me and You and Everyone We Know'],
#  ['9'],
#  ['War of the Worlds'],
#  ['March of the Penguins'],
#  ['Rebound'],
#  ['Dark Water'],
#  ['Fantastic Four'],
#  ['Murderball'],
#  ['Wedding Crashers'],
#  ['Happy Endings'],
#  ['Russian Dolls'],
#  ['Linda Linda Linda'],
#  ['Hustle & Flow'],
#  ['49 Up'],
#  ['The Island'],
#  ['Bad News Bears'],
#  ["The Devil's Rejects"],
#  ['Last Days'],
#  ['Sky High'],
#  ['Stealth'],
#  ['Must Love Dogs'],
#  ['The Aristocrats'],
#  ['Serenity'],
#  ['Broken Flowers'],
#  ['The Dukes of Hazzard'],
#  ['The Chumscrubber'],
#  ['Junebug'],
#  ['Deuce Bigalow: European Gigolo'],
#  ['The Skeleton Key'],
#  ['Four Brothers'],
#  ['The Great Raid'],
#  ['Grizzly Man'],
#  ['The Girl in the Café'],
#  ['Nana'],
#  ['The 40-Year-Old Virgin'],
#  ['Red Eye'],
#  ['Fullmetal Alchemist the Movie: Conqueror of Shamballa'],
#  ['Hidden (a.k.a. Cache)'],
#  ['Valiant'],
#  ['The Brothers Grimm'],
#  ['The Cave'],
#  ['The Constant Gardener'],
#  ['Transporter 2'],
#  ['Just Like Heaven'],
#  ['Proof'],
#  ['Lord of War'],
#  ['Cry_Wolf'],
#  ['Everything Is Illuminated'],
#  ['Family Guy Presents Stewie Griffin: The Untold Story'],
#  ['Why We Fight'],
#  ['Doom'],
#  ['Domino'],
#  ['Waiting...'],
#  ['Aeon Flux'],
#  ['An Unfinished Life'],
#  ['The Man'],
#  ['The Exorcism of Emily Rose'],
#  ['Flightplan'],
#  ['Corpse Bride'],
#  ['Green Street Hooligans'],
#  ['A History of Violence'],
#  ['Oliver Twist'],
#  ['The Greatest Game Ever Played'],
#  ['Capote'],
#  ['Into the Blue'],
#  ['The Prize Winner of Defiance Ohio'],
#  ['MirrorMask'],
#  ['Wallace & Gromit in The Curse of the Were-Rabbit'],
#  ['Kiss Kiss Bang Bang'],
#  ['No Direction Home: Bob Dylan'],
#  ['In Her Shoes'],
#  ['The Squid and the Whale'],
#  ['Two for the Money'],
#  ['Separate Lies'],
#  ['Star Wreck: In the Pirkinning'],
#  ['Brokeback Mountain'],
#  ['Elizabethtown'],
#  ['North Country'],
#  ['Good Night, and Good Luck.'],
#  ['Dreamer: Inspired by a True Story'],
#  ['The Proposition'],
#  ['Left Behind: World at War'],
#  ['Shopgirl'],
#  ['Kids in America'],
#  ['Where the Truth Lies'],
#  ['Stay'],
#  ['The Legend of Zorro'],
#  ['The Weather Man'],
#  ['Saw II'],
#  ['American Pie Presents: Band Camp'],
#  ['Manderlay'],
#  ['Revolver'],
#  ['Jarhead'],
#  ['Chicken Little'],
#  ['Joyeux Noël'],
#  ["Get Rich or Die Tryin'"],
#  ['Just Friends'],
#  ['Syriana'],
#  ['Derailed'],
#  ['Pride & Prejudice'],
#  ['Wolf Creek'],
#  ['The Descent'],
#  ['Harry Potter and the Goblet of Fire'],
#  ['Walk the Line'],
#  ['Rent'],
#  ['Zathura'],
#  ["Stephen Tobolowsky's Birthday Party"],
#  ['C.R.A.Z.Y.'],
#  ['Sarah Silverman: Jesus Is Magic'],
#  ['The Ice Harvest'],
#  ['Match Point'],
#  ['Paradise Now'],
#  ['The Chronicles of Narnia: The Lion, the Witch and the Wardrobe'],
#  ['King Kong'],
#  ['Memoirs of a Geisha'],
#  ['The Family Stone'],
#  ['The Matador'],
#  ['Mozart and the Whale'],
#  ['Munich'],
#  ['The Producers'],
#  ['Transamerica'],
#  ['Rumor Has It...'],
#  ['Cheaper by the Dozen 2'],
#  ['Fun with Dick and Jane'],
#  ['The Ringer'],
#  ['Casanova'],
#  ['Keeping Mum'],
#  ['The New World'],
#  ['Eighteen'],
#  ['Almost Normal'],
#  ['29th and Gay'],
#  ['Lady Vengeance'],
#  ['BloodRayne'],
#  ['Hostel'],
#  ['Hoodwinked!'],
#  ['Looking for Comedy in the Muslim World'],
#  ['FAQs'],
#  ['Riding Alone for Thousands of Miles'],
#  ['Little Manhattan'],
#  ['On Probation'],
#  ['Following Sean'],
#  ['Water'],
#  ['Sophie Scholl: The Final Days'],
#  ["The World's Fastest Indian"],
#  ['Nanny McPhee'],
#  ['Block Party'],
#  ['Imagine Me & You'],
#  ['Love Wrecked'],
#  ['The Call of Cthulhu'],
#  ['London'],
#  ['The Jacket'],
#  ['Tsotsi'],
#  ['The Interpreter'],
#  ['The Ring Two'],
#  ['Unknown White Male'],
#  ['The Devil and Daniel Johnston'],
#  ['The Wild Blue Yonder'],
#  ['Brick'],
#  ['Survival Island'],
#  ['Hard Candy'],
#  ['The Protector'],
#  ['Down in the Valley'],
#  ['Twelve and Holding'],
#  ['Wassup Rockers'],
#  ['Jack-Jack Attack'],
#  ['One Man Band'],
#  ["Metal: A Headbanger's Journey"],
#  ["Leonard Cohen: I'm Your Man"],
#  ['Strangers with Candy'],
#  ['End of the Spear'],
#  ['Bleak House'],
#  ['Mrs. Palfrey at the Claremont'],
#  ['Charlie and the Chocolate Factory'],
#  ['The Secret Life of Words'],
#  ['Chaos'],
#  ['White Noise'],
#  ['The Upside of Anger'],
#  ['Tideland'],
#  ["Adam's Apples"],
#  ['Elektra'],
#  ['Coach Carter'],
#  ['Assault on Precinct 13'],
#  ['Are We There Yet?'],
#  ['Hide and Seek'],
#  ['Boogeyman'],
#  ['The Wedding Date'],
#  ['The Tiger and the Snow'],
#  ['Hitch'],
#  ['Inside Deep Throat'],
#  ['Constantine'],
#  ['Because of Winn-Dixie'],
#  ['Empire Falls'],
#  ['The Pacifier'],
#  ['Be Cool'],
#  ['Hostage'],
#  ['Robots'],
#  ['War of the Worlds'],
#  ['Ice Princess'],
#  ['Miss Congeniality 2: Armed and Fabulous'],
#  ['Guess Who'],
#  ['13 Tzameti'],
#  ['Sin City'],
#  ['Sahara'],
#  ['Fever Pitch'],
#  ['George Carlin: Life Is Worth Losing']]

# %% [markdown]
# #### 4. The number of movies per director. Sort in decreasing order.

# %%
# %%cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH (m:Movie)<-[:DIRECTED]-(dir:Director)
# RETURN  dir.name, COUNT (m) AS Count
# ORDER BY Count DESC
# Out:
# 4128 rows affected.
# [['Woody Allen', 42],
#  ['Alfred Hitchcock', 38],
#  ['Martin Scorsese', 30],
#  ['Steven Spielberg', 30],
#  ['Clint Eastwood', 30],
#  ['Sidney Lumet', 25],
#  ['Steven Soderbergh', 25],
#  ['Robert Altman', 24],
#  ['Werner Herzog', 23],
#  ['Ron Howard', 22],
#  ['John Huston', 21],
#  ['Michael Apted', 21],
#  ['Ridley Scott', 21],
#  ['Spike Lee', 19],
#  ['Norman Jewison', 19],
#  ['Oliver Stone', 19],
#  ['Brian De Palma', 19],
#  ['Barry Levinson', 19],
#  ['Ethan Coen', 19],
#  ['Joel Coen', 19],
#  ['Mike Nichols', 19],
#  ['Roman Polanski', 19],
#  ['David Cronenberg', 18],
#  ['Joel Schumacher', 18],
#  ['William Wyler', 17],
#  ['Howard Hawks', 17],
#  ['John Landis', 17],
#  ['Billy Wilder', 17],
#  ['Robert Wise', 17],
#  ['Tim Burton', 17],
#  ['Francis Ford Coppola', 17],
#  ['George Cukor', 16],
#  ['Garry Marshall', 16],
#  ['Gus Van Sant', 16],
#  ['Buster Keaton', 16],
#  ['Robert Zemeckis', 16],
#  ['Robert Rodriguez', 16],
#  ['Richard Donner', 16],
#  ['Rob Reiner', 16],
#  ['Jonathan Demme', 16],
#  ['Robert Stevenson', 16],
#  ['Blake Edwards', 16],
#  ['John Ford', 15],
#  ['Pedro Almodóvar', 15],
#  ['Ingmar Bergman', 15],
#  ['Stanley Donen', 15],
#  ['John Carpenter', 15],
#  ['Ivan Reitman', 15],
#  ['Tony Scott', 15],
#  ['John Schlesinger', 14],
#  ['Akira Kurosawa', 14],
#  ['Herbert Ross', 14],
#  ['Lars von Trier', 14],
#  ['Michael Ritchie', 14],
#  ['Michael Curtiz', 14],
#  ['Sydney Pollack', 14],
#  ['Wes Craven', 14],
#  ['Fritz Lang', 14],
#  ['Peter Jackson', 14],
#  ['Federico Fellini', 14],
#  ['Alan Parker', 14],
#  ['Richard Linklater', 14],
#  ['Stephen Frears', 14],
#  ['Roger Corman', 13],
#  ['Richard Fleischer', 13],
#  ['Luis Buñuel', 13],
#  ['Roger Donaldson', 13],
#  ['Sam Raimi', 13],
#  ['Peter Farrelly', 13],
#  ['Chris Columbus', 13],
#  ['Vincente Minnelli', 13],
#  ['Walter Hill', 13],
#  ['Terry Gilliam', 13],
#  ['Dennis Dugan', 13],
#  ['Stanley Kubrick', 12],
#  ['Wim Wenders', 12],
#  ['William Friedkin', 12],
#  ['Yimou Zhang', 12],
#  ['Quentin Tarantino', 12],
#  ['Bobby Farrelly', 12],
#  ['George Miller', 12],
#  ['John Woo', 12],
#  ['Jim Jarmusch', 12],
#  ['Michael Winterbottom', 12],
#  ['John Badham', 12],
#  ['Hayao Miyazaki', 12],
#  ['Brett Ratner', 12],
#  ['Bruce Beresford', 12],
#  ['Ken Russell', 12],
#  ['Frank Oz', 12],
#  ['Lasse Hallström', 12],
#  ['Arthur Hiller', 12],
#  ['Ang Lee', 11],
#  ['Michael Haneke', 11],
#  ['Charles Chaplin', 11],
#  ['Takashi Miike', 11],
#  ['Ken Loach', 11],
#  ['Shawn Levy', 11],
#  ['Renny Harlin', 11],
#  ['David Lean', 11],
#  ['Hamilton Luske', 11],
#  ['James Ivory', 11],
#  ['Kenneth Branagh', 11],
#  ['Danny Boyle', 11],
#  ['John Boorman', 11],
#  ['David Lynch', 11],
#  ['Michael Bay', 11],
#  ['John McTiernan', 11],
#  ['Kevin Smith', 11],
#  ['Rob Cohen', 11],
#  ['François Truffaut', 11],
#  ['George Stevens', 11],
#  ['Peter Weir', 11],
#  ['Joe Dante', 11],
#  ['John Waters', 10],
#  ['Bryan Singer', 10],
#  ['John Sayles', 10],
#  ['Louis Malle', 10],
#  ['Mel Brooks', 10],
#  ['Barry Sonnenfeld', 10],
#  ['Amy Heckerling', 10],
#  ['Wolfgang Petersen', 10],
#  ['Mira Nair', 10],
#  ['Mervyn LeRoy', 10],
#  ['Fred Zinnemann', 10],
#  ['George A. Romero', 10],
#  ['Roland Emmerich', 10],
#  ['Taylor Hackford', 10],
#  ['David Fincher', 10],
#  ['Donald Petrie', 10],
#  ['Paul W.S. Anderson', 10],
#  ['Edward Zwick', 10],
#  ['Mike Leigh', 10],
#  ['Randal Kleiser', 10],
#  ['M. Night Shyamalan', 10],
#  ['Andrew Davis', 10],
#  ['Harold Ramis', 10],
#  ['Paul Schrader', 10],
#  ['Jay Roach', 10],
#  ['Antoine Fuqua', 10],
#  ['John G. Avildsen', 10],
#  ['Peter Hyams', 10],
#  ['Elia Kazan', 10],
#  ['Wilfred Jackson', 10],
#  ['Neil Jordan', 10],
#  ['Jean-Luc Godard', 10],
#  ['Todd Haynes', 10],
#  ['Joseph L. Mankiewicz', 10],
#  ['Jon Turteltaub', 10],
#  ['Michael Mann', 10],
#  ['Phillip Noyce', 10],
#  ['Stephen Herek', 10],
#  ['Paul Mazursky', 9],
#  ['Guy Hamilton', 9],
#  ['James Foley', 9],
#  ['John Frankenheimer', 9],
#  ['Christopher Nolan', 9],
#  ['Mike Figgis', 9],
#  ['Mike Newell', 9],
#  ['John Singleton', 9],
#  ['Don Bluth', 9],
#  ['Henry Hathaway', 9],
#  ['David Mamet', 9],
#  ['Frank Capra', 9],
#  ['Curtis Hanson', 9],
#  ['Alan J. Pakula', 9],
#  ['Wayne Wang', 9],
#  ['Bernardo Bertolucci', 9],
#  ['Lewis Milestone', 9],
#  ['Mark Robson', 9],
#  ['James Mangold', 9],
#  ['Peter Greenaway', 9],
#  ['Alan Rudolph', 9],
#  ['Gore Verbinski', 9],
#  ['Fred Schepisi', 9],
#  ['Sam Wood', 9],
#  ['Wes Anderson', 9],
#  ['Martin Ritt', 9],
#  ['Edward F. Cline', 9],
#  ['Peter Segal', 9],
#  ['Lawrence Kasdan', 9],
#  ['Carl Reiner', 9],
#  ['Richard Benjamin', 9],
#  ['Rainer Werner Fassbinder', 9],
#  ['Simon Wincer', 9],
#  ['Martin Campbell', 9],
#  ['Robert Redford', 9],
#  ['Joe Johnston', 9],
#  ['Robert Aldrich', 9],
#  ['Clyde Geronimi', 9],
#  ['James Cameron', 8],
#  ['Guillermo del Toro', 8],
#  ['Richard Brooks', 8],
#  ['Milos Forman', 8],
#  ['Mark Waters', 8],
#  ['Todd Phillips', 8],
#  ['Nora Ephron', 8],
#  ['Sam Peckinpah', 8],
#  ['Nick Park', 8],
#  ['Chan-wook Park', 8],
#  ['Guy Ritchie', 8],
#  ['Adam Shankman', 8],
#  ['Stephen Hopkins', 8],
#  ['Brian Levant', 8],
#  ['George Roy Hill', 8],
#  ['Peter Yates', 8],
#  ['Kathryn Bigelow', 8],
#  ['Joseph Ruben', 8],
#  ['Harold Becker', 8],
#  ['Steve Miner', 8],
#  ['Michael Caton-Jones', 8],
#  ['Steve Rash', 8],
#  ['David O. Russell', 8],
#  ['Raja Gosnell', 8],
#  ['Brian Robbins', 8],
#  ['Abel Ferrara', 8],
#  ['Cameron Crowe', 8],
#  ['Robert Benton', 8],
#  ['Michel Gondry', 8],
#  ['Jackie Chan', 8],
#  ['Anthony Mann', 8],
#  ['Costa-Gavras', 8],
#  ['Tobe Hooper', 8],
#  ['Andy Tennant', 8],
#  ['Wolfgang Reitherman', 8],
#  ['Paul Weitz', 8],
#  ['Jon Favreau', 8],
#  ['Neil LaBute', 8],
#  ['Martha Coolidge', 8],
#  ['Howard Deutch', 8],
#  ['Barbet Schroeder', 8],
#  ['David Zucker', 8],
#  ['Dwight H. Little', 8],
#  ['Nicolas Roeg', 8],
#  ['Jack Kinney', 8],
#  ['Gregg Araki', 8],
#  ['Franco Zeffirelli', 8],
#  ['Paul Verhoeven', 8],
#  ['Ron Shelton', 8],
#  ['Penelope Spheeris', 8],
#  ['Luc Besson', 8],
#  ['Alejandro G. Iñárritu', 8],
#  ['Peter Berg', 7],
#  ['Andrei Tarkovsky', 7],
#  ['Pier Paolo Pasolini', 7],
#  ['Alexander Payne', 7],
#  ['Kevin Reynolds', 7],
#  ['John Hughes', 7],
#  ['Jonathan Kaplan', 7],
#  ['Adrian Lyne', 7],
#  ['Michael Lehmann', 7],
#  ['Errol Morris', 7],
#  ['Takeshi Kitano', 7],
#  ['James Wan', 7],
#  ['John Dahl', 7],
#  ['Sylvester Stallone', 7],
#  ['J. Lee Thompson', 7],
#  ['F. Gary Gray', 7],
#  ['Hal Ashby', 7],
#  ['Arthur Penn', 7],
#  ['Richard Attenborough', 7],
#  ['Chuck Russell', 7],
#  ['Otto Preminger', 7],
#  ['Penny Marshall', 7],
#  ['Stephen Sommers', 7],
#  ['Betty Thomas', 7],
#  ['George Sidney', 7],
#  ['Paul Thomas Anderson', 7],
#  ['Kevin Macdonald', 7],
#  ['Philip Kaufman', 7],
#  ['Orson Welles', 7],
#  ['Anthony Minghella', 7],
#  ['Paul Greengrass', 7],
#  ['Lilly Wachowski', 7],
#  ['Bob Clark', 7],
#  ['Louis Leterrier', 7],
#  ['Sam Mendes', 7],
#  ['David Butler', 7],
#  ['Jean-Jacques Annaud', 7],
#  ['Roger Spottiswoode', 7],
#  ['Marc Forster', 7],
#  ['Daisuke Nishio', 7],
#  ['John Madden', 7],
#  ['Lee Tamahori', 7],
#  ['Don Siegel', 7],
#  ['Lana Wachowski', 7],
#  ['Don Coscarelli', 7],
#  ['John Irvin', 7],
#  ['Alfonso Cuarón', 7],
#  ['Lewis Gilbert', 7],
#  ['Aki Kaurismäki', 7],
#  ['Alex van Warmerdam', 7],
#  ['Walter Lang', 7],
#  ['Tom Shadyac', 7],
#  ['Mick Jackson', 7],
#  ['Richard Lester', 7],
#  ['Frank Coraci', 7],
#  ['Peter Bogdanovich', 7],
#  ['Ken Kwapis', 7],
#  ['Henry King', 7],
#  ['Raoul Walsh', 7],
#  ['Jonathan Lynn', 7],
#  ['Ishirô Honda', 7],
#  ['Tom Tykwer', 7],
#  ['Zack Snyder', 7],
#  ['Doug Liman', 7],
#  ['Luis Mandoki', 7],
#  ['Steven Brill', 6],
#  ['Ron Underwood', 6],
#  ['Mike Hodges', 6],
#  ['Rob Minkoff', 6],
#  ['Luc Dardenne', 6],
#  ['Hideaki Anno', 6],
#  ['Joshua Logan', 6],
#  ['Larry Clark', 6],
#  ['Albert Brooks', 6],
#  ['D.J. Caruso', 6],
#  ['Russell Mulcahy', 6],
#  ['Francis Lawrence', 6],
#  ['Hal Hartley', 6],
#  ['James Bridges', 6],
#  ['Christopher Guest', 6],
#  ['James L. Brooks', 6],
#  ['Brad Silberling', 6],
#  ['Jim Abrahams', 6],
#  ['John Sturges', 6],
#  ['Hugh Wilson', 6],
#  ['Justin Lin', 6],
#  ['Darren Aronofsky', 6],
#  ['Danny DeVito', 6],
#  ['Rob Williams', 6],
#  ['Andy Fickman', 6],
#  ['Brad Bird', 6],
#  ['Michael Moore', 6],
#  ['Tim Story', 6],
#  ['Joe Carnahan', 6],
#  ['David S. Ward', 6],
#  ['Ben Stiller', 6],
#  ['Richard LaGravenese', 6],
#  ['Gregory Hoblit', 6],
#  ['Joe Wright', 6],
#  ['Jaume Collet-Serra', 6],
#  ['Nicholas Ray', 6],
#  ['Stanley Kramer', 6],
#  ['John Glen', 6],
#  ['Nancy Meyers', 6],
#  ['John Lasseter', 6],
#  ['Les Mayfield', 6],
#  ['Norman Taurog', 6],
#  ['Abbas Kiarostami', 6],
#  ['Davis Guggenheim', 6],
#  ['Bruno Barreto', 6],
#  ['Alex Gibney', 6],
#  ['Peter Medak', 6],
#  ['Jean-Pierre Dardenne', 6],
#  ['Jean-Pierre Jeunet', 6],
#  ['John Musker', 6],
#  ['Aaron Seltzer', 6],
#  ['Carol Reed', 6],
#  ['Andrew Bergman', 6],
#  ['Krzysztof Kieslowski', 6],
#  ['David Yates', 6],
#  ['Bill Roberts', 6],
#  ['Adam McKay', 6],
#  ['Nick Castle', 6],
#  ['Jean Negulesco', 6],
#  ['George Lucas', 6],
#  ['Robert Luketic', 6],
#  ['Jason Friedberg', 6],
#  ['Peter Chelsom', 6],
#  ['Lloyd Kaufman', 6],
#  ['Atom Egoyan', 6],
#  ['Julien Temple', 6],
#  ['Hark Tsui', 6],
#  ['Ralph Bakshi', 6],
#  ['Carl Franklin', 6],
#  ['Robert Siodmak', 6],
#  ['Simon West', 6],
#  ['Robert Mulligan', 6],
#  ['William A. Wellman', 6],
#  ['Norman Tokar', 6],
#  ['Kenny Ortega', 6],
#  ['Sergio Leone', 6],
#  ['Patrice Leconte', 6],
#  ['Ron Clements', 6],
#  ['Norman Z. McLeod', 6],
#  ['Ted Kotcheff', 6],
#  ['Allen Hughes', 6],
#  ['David Gordon Green', 6],
#  ['Jerry Zucker', 6],
#  ['Carlos Saldanha', 6],
#  ['Gary Goldman', 6],
#  ['Christopher Cain', 6],
#  ['David R. Ellis', 6],
#  ['Kar-Wai Wong', 6],
#  ['Joe Berlinger', 6],
#  ["Pat O'Connor", 6],
#  ['Kazuya Tsurumaki', 6],
#  ['Rob Epstein', 6],
#  ['Steve Carr', 6],
#  ['Nick Cassavetes', 6],
#  ['Iain Softley', 6],
#  ['Brad Anderson', 6],
#  ['Jane Campion', 6],
#  ['Nicolas Winding Refn', 6],
#  ['Michael Hoffman', 6],
#  ['Howard Zieff', 6],
#  ['Rob Zombie', 6],
#  ['Keenen Ivory Wayans', 6],
#  ['Noah Baumbach', 6],
#  ['Simon Wells', 6],
#  ['William A. Seiter', 5],
#  ['Stuart Gordon', 5],
#  ['P.J. Hogan', 5],
#  ['Spike Jonze', 5],
#  ['Jim Sheridan', 5],
#  ['Tim Hill', 5],
#  ['Jon Avnet', 5],
#  ['Jake Kasdan', 5],
#  ['Nicholas Meyer', 5],
#  ['Martin Brest', 5],
#  ['Dominic Sena', 5],
#  ['Christian Duguay', 5],
#  ['Scott Hicks', 5],
#  ['James Marsh', 5],
#  ['David Dobkin', 5],
#  ['John Stockwell', 5],
#  ['Jonathan Frakes', 5],
#  ['Sidney J. Furie', 5],
#  ['Michael Powell', 5],
#  ['Seth Gordon', 5],
#  ['Terence Fisher', 5],
#  ['Bill Condon', 5],
#  ['Bille August', 5],
#  ['Oliver Parker', 5],
#  ['Andrew Fleming', 5],
#  ['Matthew Vaughn', 5],
#  ['Rouben Mamoulian', 5],
#  ['Michael Crichton', 5],
#  ['Irving Cummings', 5],
#  ['Joon-ho Bong', 5],
#  ['Nicole Holofcener', 5],
#  ['Delmer Daves', 5],
#  ['Claude Lelouch', 5],
#  ['Bruce Sinofsky', 5],
#  ['Mamoru Hosoda', 5],
#  ['Rocco Urbisci', 5],
#  ['Paolo Taviani', 5],
#  ['Mathieu Kassovitz', 5],
#  ['Jason Reitman', 5],
#  ['Karel Reisz', 5],
#  ['Tom McCarthy', 5],
#  ['Michael Radford', 5],
#  ['Bob Fosse', 5],
#  ['Brian Helgeland', 5],
#  ['David Frankel', 5],
#  ['Harald Zwart', 5],
#  ['Joseph Sargent', 5],
#  ['David Twohy', 5],
#  ['Paul Feig', 5],
#  ['Bob Rafelson', 5],
#  ['Judd Apatow', 5],
#  ['Mark Rydell', 5],
#  ['Richard Pearce', 5],
#  ['Jeff Tremaine', 5],
#  ['Fatih Akin', 5],
#  ['Dario Argento', 5],
#  ['Corey Yuen', 5],
#  ['Ted Demme', 5],
#  ['Tom Holland', 5],
#  ['Richard Loncraine', 5],
#  ['George P. Cosmatos', 5],
#  ['Preston Sturges', 5],
#  ['Lewis Teague', 5],
#  ['Alejandro Amenábar', 5],
#  ['Robert Schwentke', 5],
#  ['Leo McCarey', 5],
#  ['David Koepp', 5],
#  ['Albert Hughes', 5],
#  ['Tarsem Singh', 5],
#  ['Frank Henenlotter', 5],
#  ['Alex Cox', 5],
#  ['James Gray', 5],
#  ['Robert Butler', 5],
#  ['Louis C.K.', 5],
#  ['Andrew Stanton', 5],
#  ['Terry Jones', 5],
#  ['Mamoru Oshii', 5],
#  ['Jan de Bont', 5],
#  ['Peyton Reed', 5],
#  ['Stanley Tong', 5],
#  ['Edgar Wright', 5],
#  ['Emile Ardolino', 5],
#  ['Ralph Nelson', 5],
#  ['Miguel Arteta', 5],
#  ['Chris Weitz', 5],
#  ['Baltasar Kormákur', 5],
#  ['Jeremiah S. Chechik', 5],
#  ['Eric Darnell', 5],
#  ['Eli Roth', 5],
#  ['Giuseppe Tornatore', 5],
#  ['James McTeigue', 5],
#  ['George Clooney', 5],
#  ['Douglas Sirk', 5],
#  ['Jon Amiel', 5],
#  ['Jonathan Liebesman', 5],
#  ['Ronny Yu', 5],
#  ['Juan José Campanella', 5],
#  ['Yasujirô Ozu', 5],
#  ['Terence Young', 5],
#  ['Terrence Malick', 5],
#  ['Anne Fletcher', 5],
#  ['John McNaughton', 5],
#  ['Timur Bekmambetov', 5],
#  ['Denis Villeneuve', 5],
#  ['Carlos Saura', 5],
#  ['Charles Shyer', 5],
#  ['F.W. Murnau', 5],
#  ['David Ayer', 5],
#  ['John Guillermin', 5],
#  ['Éric Rohmer', 5],
#  ['Edmund Goulding', 5],
#  ['Mark Sandrich', 5],
#  ['Irwin Winkler', 5],
#  ['Victor Fleming', 5],
#  ['Michael Anderson', 5],
#  ['Shekhar Kapur', 5],
#  ['John Duigan', 5],
#  ['Denys Arcand', 5],
#  ['Jeffrey Friedman', 5],
#  ['Nicholas Hytner', 5],
#  ['Gary Fleder', 5],
#  ['Ernst Lubitsch', 5],
#  ['Hirokazu Koreeda', 5],
#  ['James Toback', 5],
#  ['Roland Joffé', 5],
#  ['François Ozon', 5],
#  ['Allison Anders', 5],
#  ['Roger Michell', 5],
#  ['Ronald Neame', 5],
#  ['Nicholas Stoller', 5],
#  ['Vittorio Taviani', 5],
#  ['Robert Townsend', 5],
#  ['Tamra Davis', 5],
#  ['Henry Koster', 5],
#  ['Sofia Coppola', 5],
#  ['Walter Salles', 5],
#  ['Charles Walters', 5],
#  ['Peter Hewitt', 5],
#  ['Baz Luhrmann', 5],
#  ['Andrew Niccol', 5],
#  ['Paul Michael Glaser', 5],
#  ['John Moore', 5],
#  ['Gurinder Chadha', 5],
#  ['Roy Ward Baker', 5],
#  ['J.J. Abrams', 5],
#  ['Michael Winner', 5],
#  ['Steve James', 5],
#  ['Ken Annakin', 5],
#  ['Stuart Rosenberg', 4],
#  ['Mark Neveldine', 4],
#  ['Bruce Robinson', 4],
#  ['Nigel Cole', 4],
#  ['Len Wiseman', 4],
#  ['Jeannot Szwarc', 4],
#  ['Ti West', 4],
#  ['Ki-duk Kim', 4],
#  ['Shigeyasu Yamauchi', 4],
#  ['Charles Martin Smith', 4],
#  ['Anand Tucker', 4],
#  ['Satoshi Kon', 4],
#  ['Rusty Cundieff', 4],
#  ['Asghar Farhadi', 4],
#  ['Michelangelo Antonioni', 4],
#  ['Henry Levin', 4],
#  ['Joan Micklin Silver', 4],
#  ['Jonathan Levine', 4],
#  ['William Castle', 4],
#  ['Richard Thorpe', 4],
#  ['James Gunn', 4],
#  ['James Algar', 4],
#  ['Alan Taylor', 4],
#  ['Sean Anders', 4],
#  ['Karyn Kusama', 4],
#  ['Rob Marshall', 4],
#  ['Terry Zwigoff', 4],
#  ['Thom Eberhardt', 4],
#  ['Peter Howitt', 4],
#  ['Sam Weisman', 4],
#  ['Emir Kusturica', 4],
#  ['Quentin Dupieux', 4],
#  ['Uwe Boll', 4],
#  ['Douglas McGrath', 4],
#  ['Rod Daniel', 4],
#  ['Joe Nussbaum', 4],
#  ['Roberto Rossellini', 4],
#  ['Tom DiCillo', 4],
#  ['Olivier Megaton', 4],
#  ['Jan Svankmajer', 4],
#  ['Tom McGrath', 4],
#  ['Anthony Russo', 4],
#  ['Anatole Litvak', 4],
#  ['John Cromwell', 4],
#  ['Nimród Antal', 4],
#  ['Nanette Burstein', 4],
#  ['Lisa Cholodenko', 4],
#  ['Agnieszka Holland', 4],
#  ['Barbara Kopple', 4],
#  ['Gary Winick', 4],
#  ['Pete Docter', 4],
#  ['István Szabó', 4],
#  ['Warren Beatty', 4],
#  ['Norman Ferguson', 4],
#  ['Lucio Fulci', 4],
#  ['Allan Moyle', 4],
#  ['Stan Dragoti', 4],
#  ['Phil Joanou', 4],
#  ['Michael Lembeck', 4],
#  ['Jacques Tourneur', 4],
#  ['Bobcat Goldthwait', 4],
#  ['Franklin J. Schaffner', 4],
#  ['Jay Oliva', 4],
#  ['Thomas Carter', 4],
#  ['Todd Solondz', 4],
#  ['Gene Saks', 4],
#  ['Rob Letterman', 4],
#  ['Bertrand Tavernier', 4],
#  ['Jean-Marc Vallée', 4],
#  ['Leonard Nimoy', 4],
#  ['Kunihiko Yuyama', 4],
#  ['Brian Gibson', 4],
#  ['Hideo Nakata', 4],
#  ['King Vidor', 4],
#  ['Jack Arnold', 4],
#  ['Oliver Hirschbiegel', 4],
#  ['Hal Needham', 4],
#  ['Tom Hooper', 4],
#  ['Matt Reeves', 4],
#  ['Alexandre Aja', 4],
#  ['Frank Marshall', 4],
#  ['Harmony Korine', 4],
#  ['Tom Gries', 4],
#  ['Larry Charles', 4],
#  ['Ben Sharpsteen', 4],
#  ['Lone Scherfig', 4],
#  ['Woo-Ping Yuen', 4],
#  ['McG', 4],
#  ['Mike Judge', 4],
#  ['Gene Kelly', 4],
#  ['Neil Marshall', 4],
#  ['Andrew Adamson', 4],
#  ['Mikael Salomon', 4],
#  ['Mark Steven Johnson', 4],
#  ['Burr Steers', 4],
#  ['Mel Gibson', 4],
#  ['W.S. Van Dyke', 4],
#  ['Jodie Foster', 4],
#  ["Gavin O'Connor", 4],
#  ['Joss Whedon', 4],
#  ['Roger Vadim', 4],
#  ['John Alan Schwartz', 4],
#  ['Greg Mottola', 4],
#  ['José Padilha', 4],
#  ['John Lee Hancock', 4],
#  ['Michael Rymer', 4],
#  ['Steve Barron', 4],
#  ['Alex Kendrick', 4],
#  ['Dean DeBlois', 4],
#  ['Henry Selick', 4],
#  ['Byron Howard', 4],
#  ['Jerry Schatzberg', 4],
#  ['Walt Becker', 4],
#  ['Jonathan Mostow', 4],
#  ['Brett Leonard', 4],
#  ['Daisy von Scherler Mayer', 4],
#  ['Bill Forsyth', 4],
#  ['Vincent McEveety', 4],
#  ['Alex Proyas', 4],
#  ['Mitsuo Hashimoto', 4],
#  ['Kirk Jones', 4],
#  ['Hector Babenco', 4],
#  ['Mikael Håfström', 4],
#  ['Stephen Daldry', 4],
#  ['Marc Lawrence', 4],
#  ['Zalman King', 4],
#  ['James Wong', 4],
#  ['James Lapine', 4],
#  ['Kevin Hooks', 4],
#  ['Phil Lord', 4],
#  ['Michael Schultz', 4],
#  ['Chris Renaud', 4],
#  ['Carroll Ballard', 4],
#  ['Lee Unkrich', 4],
#  ['Bruce McDonald', 4],
#  ['Reginald Hudlin', 4],
#  ['Jay Chandrasekhar', 4],
#  ['Frank Darabont', 4],
#  ['Steve Martino', 4],
#  ['Joe Russo', 4],
#  ['Brian Gilbert', 4],
#  ['Irvin Kershner', 4],
#  ['Phil Alden Robinson', 4],
#  ['Alain Resnais', 4],
#  ['Isabel Coixet', 4],
#  ['Kevin Lima', 4],
#  ['Nick Broomfield', 4],
#  ['Paul Weiland', 4],
#  ['Alejandro Jodorowsky', 4],
#  ['Geoff Murphy', 4],
#  ['William Asher', 4],
#  ['Thomas Vinterberg', 4],
#  ['John Whitesell', 4],
#  ['Luke Greenfield', 4],
#  ['John Erick Dowdle', 4],
#  ['Michael Dowse', 4],
#  ['Bill Melendez', 4],
#  ['Dean Parisot', 4],
#  ['Delbert Mann', 4],
#  ['Sean Penn', 4],
#  ['Catherine Hardwicke', 4],
#  ['Christopher Miller', 4],
#  ['Derek Jarman', 4],
#  ['David Wain', 4],
#  ['Jocelyn Moorhouse', 4],
#  ['Keith Gordon', 4],
#  ['Gary Nelson', 4],
#  ['Lukas Moodysson', 4],
#  ['Eugene Jarecki', 4],
#  ['George Marshall', 4],
#  ['Richard Rich', 4],
#  ['Neil Burger', 4],
#  ['Olivier Assayas', 4],
#  ['Tim Johnson', 4],
#  ['Mike Mitchell', 4],
#  ['Masayuki', 4],
#  ['Trey Parker', 4],
#  ['Tommy Chong', 4],
#  ['John Cassavetes', 4],
#  ['Jeff Kanew', 4],
#  ['Tony Bill', 4],
#  ['John Hough', 4],
#  ['Takashi Shimizu', 4],
#  ['Paul Bartel', 4],
#  ["Tommy O'Haver", 4],
#  ['Gregory Nava', 4],
#  ['Vincenzo Natali', 4],
#  ['Dennis Hopper', 4],
#  ['Jean-Pierre Melville', 4],
#  ['Robert Rossen', 4],
#  ['John Carney', 4],
#  ['Jack Clayton', 4],
#  ['Brian Taylor', 4],
#  ['Bennett Miller', 4],
#  ['Gary Trousdale', 4],
#  ['Samuel Fuller', 4],
#  ['Jay Russell', 4],
#  ['John Schultz', 3],
#  ['John Hamburg', 3],
#  ['François Girard', 3],
#  ['Steve Oedekerk', 3],
#  ['David M. Evans', 3],
#  ['Mimi Leder', 3],
#  ['Ida Lupino', 3],
#  ['Lee Daniels', 3],
#  ['David Nutter', 3],
#  ['Steve McQueen', 3],
#  ['Kinji Fukasaku', 3],
#  ['Pierre Morel', 3],
#  ['Doug Ellin', 3],
#  ['George Hickenlooper', 3],
#  ['Conrad Vernon', 3],
#  ['Stephen Kessler', 3],
#  ['Tim Blake Nelson', 3],
#  ['Alan Alda', 3],
#  ['Robert Mandel', 3],
#  ['Frank Tashlin', 3],
#  ['Nancy Savoca', 3],
#  ['Akiva Schaffer', 3],
#  ['George Armitage', 3],
#  ['Jean-Paul Rappeneau', 3],
#  ['Jack Sholder', 3],
#  ['Pawel Pawlikowski', 3],
#  ['Clive Barker', 3],
#  ['Francis Veber', 3],
#  ['Kelly Asbury', 3],
#  ['René Clément', 3],
#  ['Bruce Brown', 3],
#  ['Richard Kelly', 3],
#  ['Cary Joji Fukunaga', 3],
#  ['David Carson', 3],
#  ['Neill Blomkamp', 3],
#  ['John Lounsbery', 3],
#  ['William Dear', 3],
#  ['David Maysles', 3],
#  ['Scott McGehee', 3],
#  ['Bryan Forbes', 3],
#  ['Mark Herman', 3],
#  ['Billy Crystal', 3],
#  ['Roberto Benigni', 3],
#  ['Fred Dekker', 3],
#  ['Albert Maysles', 3],
#  ['David Swift', 3],
#  ['Chris Buck', 3],
#  ['Sammo Kam-Bo Hung', 3],
#  ['Cédric Klapisch', 3],
#  ['David Slade', 3],
#  ['Guy Ferland', 3],
#  ['Sidney Franklin', 3],
#  ['Edward Buzzell', 3],
#  ['Andrzej Bartkowiak', 3],
#  ['Rick Famuyiwa', 3],
#  ['Michael Cuesta', 3],
#  ['Tom Dey', 3],
#  ['Stewart Raffill', 3],
#  ['Angus MacLane', 3],
#  ['Griffin Dunne', 3],
#  ['Norman René', 3],
#  ['Ralph Ziman', 3],
#  ['Gaspar Noé', 3],
#  ['Whit Stillman', 3],
#  ['Kurt Neumann', 3],
#  ['John Milius', 3],
#  ['Antonia Bird', 3],
#  ['Gillian Armstrong', 3],
#  ['Nick Hurran', 3],
#  ['Scott Cooper', 3],
#  ['Carl Theodor Dreyer', 3],
#  ['Jared Hess', 3],
#  ['Chris Sanders', 3],
#  ['Billy Corben', 3],
#  ['Jack Hill', 3],
#  ['Yoshiaki Kawajiri', 3],
#  ['Allan Dwan', 3],
#  ['Tim Robbins', 3],
#  ['Will Gluck', 3],
#  ['Andrew Dominik', 3],
#  ['Wai-Keung Lau', 3],
#  ['Tony Richardson', 3],
#  ['Bertrand Blier', 3],
#  ['Luis Llosa', 3],
#  ['Edward Burns', 3],
#  ['Sylvain Chomet', 3],
#  ['David Bowers', 3],
#  ['James DeMonaco', 3],
#  ['Julian Schnabel', 3],
#  ['Mark Dindal', 3],
#  ['Frank Pierson', 3],
#  ['Michael Cimino', 3],
#  ['Randall Wallace', 3],
#  ['Busby Berkeley', 3],
#  ['Richard Rush', 3],
#  ['Ben Affleck', 3],
#  ['Mario Bava', 3],
#  ['Kevin Costner', 3],
#  ['Paul McGuigan', 3],
#  ['Campbell Scott', 3],
#  ['Satyajit Ray', 3],
#  ['Duncan Jones', 3],
#  ['Daniel Petrie', 3],
#  ['Lauren Montgomery', 3],
#  ['Bronwen Hughes', 3],
#  ['Glenn Ficarra', 3],
#  ['Jim Henson', 3],
#  ['Stefan Ruzowitzky', 3],
#  ['Paul Haggis', 3],
#  ['Richard Quine', 3],
#  ['Darren Lynn Bousman', 3],
#  ['Claude Berri', 3],
#  ['Claude Chabrol', 3],
#  ['Joseph Zito', 3],
#  ['Frank Perry', 3],
#  ['John R. Cherry III', 3],
#  ['Barbra Streisand', 3],
#  ['Robert Towne', 3],
#  ['Andrew V. McLaglen', 3],
#  ['Michael Haigney', 3],
#  ['Richard Curtis', 3],
#  ['Gordon Chan', 3],
#  ['Fenton Bailey', 3],
#  ['Gillies MacKinnon', 3],
#  ['Alexander Mackendrick', 3],
#  ['Lina Wertmüller', 3],
#  ['Amy Holden Jones', 3],
#  ['Max Ophüls', 3],
#  ['Jesse Dylan', 3],
#  ['Katsuhiro Ôtomo', 3],
#  ['Frank Miller', 3],
#  ['Henry Joost', 3],
#  ['Irwin Allen', 3],
#  ['Paul Almond', 3],
#  ['Jeff Pollack', 3],
#  ['Gary Ross', 3],
#  ['Sean McNamara', 3],
#  ['Edward D. Wood Jr.', 3],
#  ['David Silverman', 3],
#  ['Mike Binder', 3],
#  ['Michael Cristofer', 3],
#  ['Jules Bass', 3],
#  ['Tom Six', 3],
#  ['Breck Eisner', 3],
#  ['Niki Caro', 3],
#  ['John Pasquin', 3],
#  ['Arthur Rankin Jr.', 3],
#  ['Tony Randel', 3],
#  ['Don Chaffey', 3],
#  ['Don Roos', 3],
#  ['André Téchiné', 3],
#  ['Sam Liu', 3],
#  ['Robert Clouse', 3],
#  ['Charles Barton', 3],
#  ['John Requa', 3],
#  ['Jeff Burr', 3],
#  ['Majid Majidi', 3],
#  ['Adam Wingard', 3],
#  ['David Miller', 3],
#  ['Richard Eyre', 3],
#  ['John N. Smith', 3],
#  ['Edward Sedgwick', 3],
#  ['Robert Lieberman', 3],
#  ['John Wayne', 3],
#  ['Kaige Chen', 3],
#  ['Ming-liang Tsai', 3],
#  ['Craig Brewer', 3],
#  ['Ruben Fleischer', 3],
#  ['Godfrey Reggio', 3],
#  ['Vicky Jenson', 3],
#  ['Andrey Konchalovskiy', 3],
#  ['Julie Taymor', 3],
#  ['Rod Lurie', 3],
#  ['Gabriele Muccino', 3],
#  ['Richard Marquand', 3],
#  ['Ulu Grosbard', 3],
#  ['Leos Carax', 3],
#  ['Lenny Abrahamson', 3],
#  ['Sam Fell', 3],
#  ['Bryan Spicer', 3],
#  ['Uli Edel', 3],
#  ['Brett Morgen', 3],
#  ['Victor Salva', 3],
#  ['Ricky Gervais', 3],
#  ['Philippe Mora', 3],
#  ['Volker Schlöndorff', 3],
#  ['Kenneth Johnson', 3],
#  ['Ringo Lam', 3],
#  ['Christopher McQuarrie', 3],
#  ['Ruggero Deodato', 3],
#  ['Ken Scott', 3],
#  ['Michael Polish', 3],
#  ['Malcolm D. Lee', 3],
#  ['Anthony C. Ferrante', 3],
#  ['Charles Crichton', 3],
#  ['Marty Callner', 3],
#  ['George Seaton', 3],
#  ['Ariel Schulman', 3],
#  ['Rowdy Herrington', 3],
#  ['Martin McDonagh', 3],
#  ['Jafar Panahi', 3],
#  ['Louis Morneau', 3],
#  ['Michael Herz', 3],
#  ['Ted Post', 3],
#  ['Jon M. Chu', 3],
#  ['James Frawley', 3],
#  ['Mark Osborne', 3],
#  ['Rodrigo García', 3],
#  ['Sebastian Schipper', 3],
#  ['Laurence Olivier', 3],
#  ['Pierre Coffin', 3],
#  ['Dan Ireland', 3],
#  ['Jeff Wadlow', 3],
#  ['Allan Arkush', 3],
#  ['Mark Pellington', 3],
#  ['Tommy Lee Wallace', 3],
#  ['Mads Brügger', 3],
#  ['Stuart Baird', 3],
#  ['Mark L. Lester', 3],
#  ['Steve Pink', 3],
#  ['Emilio Estevez', 3],
#  ['Anton Corbijn', 3],
#  ['Taika Waititi', 3],
#  ['David Seltzer', 3],
#  ['George Gallo', 3],
#  ['Colin Higgins', 3],
#  ['Vittorio De Sica', 3],
#  ['Alan Metter', 3],
#  ['Henri-Georges Clouzot', 3],
#  ['Doug Pray', 3],
#  ['Edward Dmytryk', 3],
#  ['Jee-woon Kim', 3],
#  ['Emeric Pressburger', 3],
#  ['Kôji Morimoto', 3],
#  ['Sergey Bodrov', 3],
#  ['Claire Denis', 3],
#  ['Álex de la Iglesia', 3],
#  ['Robert Bresson', 3],
#  ['Christopher Smith', 3],
#  ['Craig Gillespie', 3],
#  ['Gavin Hood', 3],
#  ['Bruce McCulloch', 3],
#  ['Chris Wedge', 3],
#  ['Shane Black', 3],
#  ...]

# %% [markdown]
# #### 5. The number of directors by movie. Sort in decreasing order.

# %%
# %%cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH (m:Movie)<-[:DIRECTED]-(dir:Director)
# RETURN  m.title, COUNT (dir) AS Count
# ORDER BY Count DESC
# Out:
# 8841 rows affected.
# [['To Each His Own Cinema', 36],
#  ['Life in a Day', 31],
#  ['Paris, I Love You', 22],
#  ['Movie 43', 13],
#  ['11\'09"01 - September 11', 11],
#  ['New York, I Love You', 11],
#  ['Fantasia', 11],
#  ['V/H/S', 10],
#  ['Aria', 10],
#  ['Band of Brothers', 8],
#  ['Fantasia 2000', 8],
#  ['Hamlet', 8],
#  ['The Terror', 7],
#  ['Duel in the Sun', 7],
#  ['Bambi', 7],
#  ['Pinocchio', 7],
#  ['The Animatrix', 7],
#  ['Dumbo', 7],
#  ['Peter Pan', 6],
#  ['Batman: Mask of the Phantasm', 6],
#  ['The Pacific', 6],
#  ['The Phantom of the Opera', 6],
#  ['Casino Royale', 6],
#  ['Freakonomics', 6],
#  ['Snow White and the Seven Dwarfs', 6],
#  ['Ben-Hur: A Tale of the Christ', 5],
#  ['The Wizard of Oz', 5],
#  ['The Three Musketeers', 5],
#  ['Amazon Women on the Moon', 5],
#  ['Grey Gardens', 5],
#  ['The Longest Day', 5],
#  ['Grindhouse', 5],
#  ['Make Mine Music', 5],
#  ['The Three Caballeros', 5],
#  ['Vampire in Venice', 5],
#  ['Alice in Wonderland', 5],
#  ['Cinderella', 5],
#  ['Magical Mystery Tour', 5],
#  ['Life Is Sacred', 4],
#  ['Evangelion: 3.0 You Can (Not) Redo', 4],
#  ['Carrie', 4],
#  ['A Star Is Born', 4],
#  ["We're Back! A Dinosaur's Story", 4],
#  ['Beavis and Butt-Head Do America', 4],
#  ['How the West Was Won', 4],
#  ['The Great Mouse Detective', 4],
#  ['Doctor Strange', 4],
#  ['Beauty and the Beast', 4],
#  ['Toronto Stories', 4],
#  ['Jane Eyre', 4],
#  ["King Solomon's Mines", 4],
#  ['The Good Earth', 4],
#  ['Twilight Zone: The Movie', 4],
#  ['Four Rooms', 4],
#  ['Cowboy Bebop: The Movie', 4],
#  ['Roots', 4],
#  ['American Dream', 4],
#  ['Trailer Park Boys: Live at the North Pole', 4],
#  ['Fun and Fancy Free', 4],
#  ['Everest', 4],
#  ['King Kong', 4],
#  ['Saludos Amigos', 4],
#  ['101 Dalmatians', 4],
#  ['The Kid Brother', 4],
#  ["Metal: A Headbanger's Journey", 3],
#  ['The Rape of Europa', 3],
#  ['The General', 3],
#  ['The Trip', 3],
#  ['The Little Shop of Horrors', 3],
#  ['The Phantom Tollbooth', 3],
#  ['The Blob', 3],
#  ['Tora! Tora! Tora!', 3],
#  ['Evangelion: 1.0 You Are (Not) Alone', 3],
#  ['Neon Genesis Evangelion: Death & Rebirth', 3],
#  ['Evangelion: 2.0 You Can (Not) Advance', 3],
#  ['The Fiendish Plot of Dr. Fu Manchu', 3],
#  ['Mister Roberts', 3],
#  ['The Fox and the Hound', 3],
#  ['New York Stories', 3],
#  ['Waste Land', 3],
#  ['The Night of the Hunter', 3],
#  ['Gone with the Wind', 3],
#  ["Everyone's Hero", 3],
#  ['Hearts of Darkness: A Filmmakers Apocalypse', 3],
#  ["Madagascar 3: Europe's Most Wanted", 3],
#  ['Shrek 2', 3],
#  ['Young at Heart', 3],
#  ['Scarface', 3],
#  ['Freaky Friday', 3],
#  ['Black Mirror', 3],
#  ['The Interview', 3],
#  ['Six by Sondheim', 3],
#  ['The Island of Dr. Moreau', 3],
#  ['Fever Pitch', 3],
#  ['Spirits of the Dead', 3],
#  ['The Mummy', 3],
#  ['Three... Extremes', 3],
#  ['The Atomic Cafe', 3],
#  ['The Adventures of Ichabod and Mr. Toad', 3],
#  ['Appleseed', 3],
#  ['Top Secret!', 3],
#  ['Airplane!', 3],
#  ['Ruthless People', 3],
#  ['The Enforcer', 3],
#  ['The Rescuers', 3],
#  ['The Old Man and the Sea', 3],
#  ['Salesman', 3],
#  ['Gimme Shelter', 3],
#  ['Caligula', 3],
#  ['Les Misérables', 3],
#  ['Boys Life', 3],
#  ['Cleopatra', 3],
#  ['The Magnificent Ambersons', 3],
#  ['Titan A.E.', 3],
#  ['All Dogs Go to Heaven', 3],
#  ['Anastasia', 3],
#  ['Rock-A-Doodle', 3],
#  ['The Fly', 3],
#  ['True Grit', 3],
#  ['Tokyo!', 3],
#  ['Promises', 3],
#  ['Sin City', 3],
#  ['Babes in Toyland', 3],
#  ['Happy Feet', 3],
#  ['The Return of Jafar', 3],
#  ['No Nukes', 3],
#  ['D.O.A.', 3],
#  ["Charlotte's Web", 3],
#  ['Monsters, Inc.', 3],
#  ['Planet 51', 3],
#  ['School For Scoundrels', 3],
#  ['Heaven Can Wait', 3],
#  ['Evocateur: The Morton Downey Jr. Movie', 3],
#  ['Def-Con 4', 3],
#  ['The Jungle Book', 3],
#  ['Man Bites Dog', 3],
#  ['Zootopia', 3],
#  ['Shark Tale', 3],
#  ['The Central Park Five', 3],
#  ['Faces of Death 4', 3],
#  ['The Fast and the Furious', 3],
#  ['The Greatest Story Ever Told', 3],
#  ['Lady and the Tramp', 3],
#  ['Brave', 3],
#  ['The Green Berets', 3],
#  ['Visions of Light: The Art of Cinematography', 3],
#  ['Blue in the Face', 3],
#  ['The Paleface', 3],
#  ['Toy Story 2', 3],
#  ['Wonderland', 3],
#  ['The Road to El Dorado', 3],
#  ['What the Bleep Do We Know!?', 3],
#  ['The Ladykillers', 3],
#  ['Dracula', 3],
#  ['Werner - Beinhart!', 3],
#  ['Mutiny on the Bounty', 3],
#  ['Godzilla', 3],
#  ['Memories', 3],
#  ['EuroTrip', 3],
#  ['Ice Age: The Great Egg-Scapade', 3],
#  ['The Act of Killing', 3],
#  ['Cloud Atlas', 3],
#  ['A Christmas Carol', 3],
#  ['Hercules', 3],
#  ['Open Season', 3],
#  ['Hoodwinked!', 3],
#  ['Tarzan and His Mate', 3],
#  ['The Freshman', 3],
#  ['The Yes Men', 3],
#  ['The Yes Men Fix the World', 3],
#  ['Winged Migration', 3],
#  ['The Great Gatsby', 3],
#  ['The Prince of Egypt', 3],
#  ['Around the World in 80 Days', 3],
#  ['The Hunchback of Notre Dame', 3],
#  ['Pride and Prejudice', 2],
#  ['Mighty Joe Young', 2],
#  ['Snowriders', 2],
#  ['Call Me Kuchu', 2],
#  ['Susannah of the Mounties', 2],
#  ['The Little Princess', 2],
#  ['Prom Night III: The Last Kiss', 2],
#  ['Dolls', 2],
#  ['Strange Brew', 2],
#  ['The Anniversary Party', 2],
#  ["Nim's Island", 2],
#  ['Apollo 13: To the Edge and Back', 2],
#  ['Get Carter', 2],
#  ['Damien: Omen II', 2],
#  ['Quick Change', 2],
#  ['The Amityville Horror', 2],
#  ['Maybe Baby', 2],
#  ['Mark of the Devil', 2],
#  ['Cinemania', 2],
#  ['Nothing to Lose', 2],
#  ['Ong-Bak 2: The Beginning', 2],
#  ['Chill Out!', 2],
#  ['On Dangerous Ground', 2],
#  ['Crank', 2],
#  ['Ghost Rider: Spirit of Vengeance', 2],
#  ['Gamer', 2],
#  ['Crank: High Voltage', 2],
#  ['The Rugrats Movie', 2],
#  ['Student of the Year', 2],
#  ['Gloria', 2],
#  ['12 Angry Men', 2],
#  ['Lolita', 2],
#  ['Ratatouille', 2],
#  ['Shame', 2],
#  ['Total Recall', 2],
#  ['Underworld', 2],
#  ['Flesh for Frankenstein', 2],
#  ['The Kingdom', 2],
#  ['Miami Connection', 2],
#  ['Brother', 2],
#  ['The Lion King', 2],
#  ['Two Days, One Night', 2],
#  ['The Son', 2],
#  ["Lorna's Silence", 2],
#  ['The Kid With a Bike', 2],
#  ['Rosetta', 2],
#  ['The Wasp Woman', 2],
#  ['Battle Beyond the Stars', 2],
#  ['The Raven', 2],
#  ['Daybreakers', 2],
#  ['Predestination', 2],
#  ['The Gate of Heavenly Peace', 2],
#  ['The War at Home', 2],
#  ['Battle Royale 2: Requiem', 2],
#  ['Piranha II: The Spawning', 2],
#  ['Titanic', 2],
#  ['Vacation', 2],
#  ['Solaris', 2],
#  ["Ivan's Childhood", 2],
#  ['Chaos', 2],
#  ['The Big Town', 2],
#  ['Slumdog Millionaire', 2],
#  ['Shin Godzilla', 2],
#  ['Neon Genesis Evangelion: The End of Evangelion', 2],
#  ['20,000 Leagues Under the Sea', 2],
#  ['Joan Rivers: A Piece of Work', 2],
#  ['Kung Fu Panda', 2],
#  ['The Croods', 2],
#  ['Ken Park', 2],
#  ['The Fluffer', 2],
#  ['The Black Cauldron', 2],
#  ['A Personal Journey with Martin Scorsese Through American Movies', 2],
#  ['A Letter to Elia', 2],
#  ['Cape Fear', 2],
#  ['Revenge of the Green Dragons', 2],
#  ['Cyrus', 2],
#  ['Jeff, Who Lives at Home', 2],
#  ['Wuthering Heights', 2],
#  ['Delirious', 2],
#  ['The Maltese Falcon', 2],
#  ['Digimon: The Movie', 2],
#  ['Little Women', 2],
#  ['Born Yesterday', 2],
#  ['The Women', 2],
#  ['Gaslight', 2],
#  ['The First Nudie Musical', 2],
#  ['Them', 2],
#  ['City of God', 2],
#  ['Hairspray', 2],
#  ['Monsters vs. Aliens', 2],
#  ['Maniac', 2],
#  ['Monty Python Live at the Hollywood Bowl', 2],
#  ['Sinbad: Legend of the Seven Seas', 2],
#  ['Red River', 2],
#  ['The Thing from Another World', 2],
#  ['The Big Sleep', 2],
#  ['This Is the End', 2],
#  ['Tokyo Godfathers', 2],
#  ['Armour of God', 2],
#  ['Dinosaur', 2],
#  ['Reckless', 2],
#  ['Prison Break: The Final Break', 2],
#  ['Mother', 2],
#  ['Daria: Is It Fall Yet?', 2],
#  ['The Lovers and the Despot', 2],
#  ["What's Up, Tiger Lily?", 2],
#  ['Alice', 2],
#  ['Love and a Bullet', 2],
#  ['The Day of the Triffids', 2],
#  ['The Wonderful World of the Brothers Grimm', 2],
#  ['Journey to the Center of the Earth', 2],
#  ["What's New, Pussycat", 2],
#  ['Psycho', 2],
#  ['Birdman of Alcatraz', 2],
#  ['The Manchurian Candidate', 2],
#  ['State of Grace', 2],
#  ['Popstar: Never Stop Never Stopping', 2],
#  ['Endurance', 2],
#  ["No Man's Land", 2],
#  ['The Bourne Identity', 2],
#  ['The Most Dangerous Man in America: Daniel Ellsberg and the Pentagon Papers',
#   2],
#  ['A Perfect Candidate', 2],
#  ['Sleepwalk with Me', 2],
#  ['Gone in 60 Seconds', 2],
#  ["That's Entertainment! III", 2],
#  ['Tangled', 2],
#  ['Tangled Ever After', 2],
#  ['Why Stop Now', 2],
#  ['The Golem', 2],
#  ['Boys', 2],
#  ['Steamboat Bill, Jr.', 2],
#  ['The Getaway', 2],
#  ['Wallace & Gromit in The Curse of the Were-Rabbit', 2],
#  ['Chicken Run', 2],
#  ['They Were Expendable', 2],
#  ['Stagecoach', 2],
#  ['The Return of Godzilla', 2],
#  ['The Shop on Main Street', 2],
#  ['The James Dean Story', 2],
#  ['Cars 2', 2],
#  ['Carnosaur', 2],
#  ['Black Christmas', 2],
#  ['House on Haunted Hill', 2],
#  ['The Book of Life', 2],
#  ['Czech Dream', 2],
#  ['The Thing', 2],
#  ['Thirst', 2],
#  ['An American Tail: Fievel Goes West', 2],
#  ['Spirit: Stallion of the Cimarron', 2],
#  ['Spellbound', 2],
#  ['The Weather Underground', 2],
#  ['The Big Gay Musical', 2],
#  ['The Punisher', 2],
#  ['Black Narcissus', 2],
#  ['The Life and Death of Colonel Blimp', 2],
#  ["I Know Where I'm Going!", 2],
#  ['Festival Express', 2],
#  ['Swept Away', 2],
#  ['Arthur Christmas', 2],
#  ['Mulan', 2],
#  ['The Fan', 2],
#  ['Charly', 2],
#  ['The Producers', 2],
#  ['Family Band: The Cowsills Story', 2],
#  ['FAQs', 2],
#  ['Man of the Year', 2],
#  ['The Hunted', 2],
#  ['The Hound of the Baskervilles', 2],
#  ['Making a Murderer', 2],
#  ['A Night at the Roxbury', 2],
#  ['The Tunnel', 2],
#  ['Insomnia', 2],
#  ['This Is Elvis', 2],
#  ['It Came from Hollywood', 2],
#  ['John Wick', 2],
#  ['Bad Boys', 2],
#  ['Halloween II', 2],
#  ['One Man Band', 2],
#  ['The 10th Kingdom', 2],
#  ['Over the Hedge', 2],
#  ['Cemetery Junction', 2],
#  ['Black Beauty', 2],
#  ['Born Free', 2],
#  ['The Many Adventures of Winnie the Pooh', 2],
#  ['What Maisie Knew', 2],
#  ['The Deep End', 2],
#  ['Suture', 2],
#  ['The Girl with the Dragon Tattoo', 2],
#  ['Into the Woods', 2],
#  ['Rollerball', 2],
#  ['The Thomas Crown Affair', 2],
#  ['25 Watts', 2],
#  ['The Stepford Wives', 2],
#  ['Ju Dou', 2],
#  ['Hero', 2],
#  ["Bush's Brain", 2],
#  ['The Importance of Being Earnest', 2],
#  ['Othello', 2],
#  ['Village of the Damned', 2],
#  ['The Mark of Zorro', 2],
#  ['Underworld: Awakening', 2],
#  ['Buster Keaton: A Hard Act to Follow', 2],
#  ['Fulltime Killer', 2],
#  ['Assault on Precinct 13', 2],
#  ['Hustler White', 2],
#  ['loudQUIETloud: A Film About the Pixies', 2],
#  ['Forgotten Silver', 2],
#  ['The Out-of-Towners', 2],
#  ['So Dear to My Heart', 2],
#  ['Legend of the Red Dragon', 2],
#  ['Kung Fu Cult Master', 2],
#  ['The Navigator', 2],
#  ['Shaft', 2],
#  ['Delicatessen', 2],
#  ['The City of Lost Children', 2],
#  ['Company Man', 2],
#  ['Emma', 2],
#  ['The Parent Trap', 2],
#  ['A Troll in Central Park', 2],
#  ['Thumbelina', 2],
#  ["Gulliver's Travels", 2],
#  ['Crash', 2],
#  ['Startup.com', 2],
#  ['Frozen', 2],
#  ["Surf's Up", 2],
#  ['Tarzan', 2],
#  ['The Italian Job', 2],
#  ['Rape Me', 2],
#  ['Anomalisa', 2],
#  ['Project A', 2],
#  ['Kiss of Death', 2],
#  ['Airport', 2],
#  ['The Rainmaker', 2],
#  ['The Scarlet Letter', 2],
#  ['A Fish Called Wanda', 2],
#  ['The Man Who Knew Too Much', 2],
#  ['Mr. & Mrs. Smith', 2],
#  ['9', 2],
#  ['Foxfire', 2],
#  ['Persepolis', 2],
#  ['Tango & Cash', 2],
#  ['Mad Max Beyond Thunderdome', 2],
#  ['The 13th Warrior', 2],
#  ['ParaNorman', 2],
#  ['Trouble the Water', 2],
#  ['The Curse of the Cat People', 2],
#  ['The Forsyte Saga', 2],
#  ['No Way Out', 2],
#  ['Twinsters', 2],
#  ['The Rescuers Down Under', 2],
#  ['Pocahontas', 2],
#  ['Goodbye, Mr. Chips', 2],
#  ['Faust', 2],
#  ['The Host', 2],
#  ['Madagascar: Escape 2 Africa', 2],
#  ['Madagascar', 2],
#  ['Stealing Home', 2],
#  ['Go West', 2],
#  ['Inglourious Basterds', 2],
#  ['Sabrina', 2],
#  ['The Three Stooges', 2],
#  ['Stuck on You', 2],
#  ['The Heartbreak Kid', 2],
#  ['Shallow Hal', 2],
#  ['Osmosis Jones', 2],
#  ['Me, Myself & Irene', 2],
#  ['Hall Pass', 2],
#  ['Dumb and Dumber To', 2],
#  ["There's Something About Mary", 2],
#  ['Kingpin', 2],
#  ['Dumb & Dumber', 2],
#  ['You, Me and Dupree', 2],
#  ['Captain America: The Winter Soldier', 2],
#  ['Captain America: Civil War', 2],
#  ['Welcome to Collinwood', 2],
#  ['Employee of the Month', 2],
#  ['3:10 to Yuma', 2],
#  ['Finding Dory', 2],
#  ['The Five Obstructions', 2],
#  ['Paradise Lost 3: Purgatory', 2],
#  ['Metallica: Some Kind of Monster', 2],
#  ['Paradise Lost 2: Revelations', 2],
#  ["Brother's Keeper", 2],
#  ['Paradise Lost: The Child Murders at Robin Hood Hills', 2],
#  ['Hearts and Minds', 2],
#  ['Aileen: Life and Death of a Serial Killer', 2],
#  ['Final Fantasy: The Spirits Within', 2],
#  ['The Butterfly Effect', 2],
#  ['Fair Game', 2],
#  ['Control', 2],
#  ["It's Kind of a Funny Story", 2],
#  ['Arthur', 2],
#  ['The Kid Stays in the Picture', 2],
#  ['On the Ropes', 2],
#  ['Keep the River on Your Right: A Modern Cannibal Tale', 2],
#  ['The Immigrant', 2],
#  ['The Kid', 2],
#  ['Little Nemo: Adventures in Slumberland', 2],
#  ['Turbo: A Power Rangers Movie', 2],
#  ['Wanted', 2],
#  ['The Battered Bastards of Baseball', 2],
#  ['The Way, Way Back', 2],
#  ['Restrepo', 2],
#  ['All Dogs Go to Heaven 2', 2],
#  ['Fiorile', 2],
#  ['Night of the Shooting Stars', 2],
#  ['Padre padrone', 2],
#  ['Good Morning, Babylon', 2],
#  ['Caesar Must Die', 2],
#  ['Undefeated', 2],
#  ['Priest', 2],
#  ["The Lion King II: Simba's Pride", 2],
#  ['Shut Up & Sing', 2],
#  ['The Gambler', 2],
#  ['Far from the Madding Crowd', 2],
#  ['Unprecedented: The 2000 Presidential Election', 2],
#  ['Cars', 2],
#  ['Fantastic Four', 2],
#  ['Prom Night', 2],
#  ['How to Train Your Dragon', 2],
#  ['Lilo & Stitch', 2],
#  ['Watchmen: Tales of the Black Freighter', 2],
#  ['The Big Bang Theory', 2],
#  ['The Revolution Will Not Be Televised', 2],
#  ["Mike's New Car", 2],
#  ['Inside Out', 2],
#  ['Up', 2],
#  ['Sunshine', 2],
#  ['War of the Worlds', 2],
#  ['Flawless', 2],
#  ['1984', 2],
#  ['The Postman', 2],
#  ['Dragon Hunters', 2],
#  ['Ninja Scroll', 2],
#  ['Kung Fu Panda 3', 2],
#  ["Boundin'", 2],
#  ['Mulan II', 2],
#  ['Finding Vivian Maier', 2],
#  ['The Goat', 2],
#  ['How the Grinch Stole Christmas!', 2],
#  ['American Mary', 2],
#  ['Steam of Life', 2],
#  ['Home on the Range', 2],
#  ['Every Little Step', 2],
#  ['The Adventures of Felix', 2],
#  ['West Side Story', 2],
#  ['The White Sound', 2],
#  ['The Corporation', 2],
#  ['Manufacturing Consent: Noam Chomsky and the Media', 2],
#  ['Infernal Affairs 2', 2],
#  ['Infernal Affairs', 2],
#  ['The Slaughter Rule', 2],
#  ['Legend', 2],
#  ['Cherrybomb', 2],
#  ['The Illusionist', 2],
#  ['The Secret Life of Walter Mitty', 2],
#  ['Cat People', 2],
#  ['The Court Jester', 2],
#  ['House', 2],
#  ['Planet of the Apes', 2],
#  ['Screwed', 2],
#  ['House Party 2', 2],
#  ['Home', 2],
#  ['The Karate Kid', 2],
#  ['Flushed Away', 2],
#  ['Girl Model', 2],
#  ['A Fantastic Fear of Everything', 2],
#  ['Metropolis', 2],
#  ['A Decade Under the Influence', 2],
#  ['The Class', 2],
#  ['Who Am I?', 2],
#  ["Family Guy Presents: It's a Trap", 2],
#  ['A.R.O.G.', 2],
#  ['Clash of the Titans', 2],
#  ['Arranged', 2],
#  ['Dreamcatcher', 2],
#  ['The Sum of Us', 2],
#  ['Sound of Noise', 2],
#  ['Born into Brothels', 2],
#  ['Shall We Dance?', 2],
#  ['Shrek the Third', 2],
#  ['Cabin in the Sky', 2],
#  ['The Big Boss', 2],
#  ['Kon-Tiki', 2],
#  ['Bandidas', 2],
#  ['House of Wax', 2],
#  ['Deadgirl', 2],
#  ['Kismet', 2],
#  ['Damn Yankees!', 2],
#  ['Bedazzled', 2],
#  ['On the Town', 2],
#  ['The Pajama Game', 2],
#  ['Saturn 3', 2],
#  ["Singin' in the Rain", 2],
#  ['Deep Water', 2],
#  ['The Pink Panther', 2],
#  ['Cheaper by the Dozen', 2],
#  ['Intouchables', 2],
#  ['Samba', 2],
#  ['Pokemon 4 Ever', 2],
#  ['Pokémon 3: The Movie', 2],
#  ['Pokémon the Movie 2000', 2],
#  ['Pokémon: The First Movie', 2],
#  ['Big Night', 2],
#  ['Dark Water', 2],
#  ['Brother Bear', 2],
#  ['Persuasion', 2],
#  ['True Crime', 2],
#  ['Best of Enemies', 2],
#  ['Guantanamera', 2],
#  ['Strawberry and Chocolate', 2],
#  ['Batman: Year One', 2],
#  ['Justice League: Crisis on Two Earths', 2],
#  ['Focus', 2],
#  ['I Love You Phillip Morris', 2],
#  ['Crazy, Stupid, Love.', 2],
#  ['The Dark Crystal', 2],
#  ["Long Night's Journey Into Day", 2],
#  ['Oliver Twist', 2],
#  ['Ghostbusters', 2],
#  ['Sisters', 2],
#  ['The U.S. vs. John Lennon', 2],
#  ['The Invasion', 2],
#  ['The Waterdance', 2],
#  ['Invasion of the Body Snatchers', 2],
#  ['Bandits', 2],
#  ['Avalon', 2],
#  ['Piranha', 2],
#  ['The Hills Have Eyes', 2],
#  ['What We Do in the Shadows', 2],
#  ['What Women Want', 2],
#  ['Rugrats in Paris: The Movie', 2],
#  ['Shogun Assassin', 2],
#  ['Josie and the Pussycats', 2],
#  ["Can't Hardly Wait", 2],
#  ['Michael Jordan to the Max', 2],
#  ['Gypsy', 2],
#  ['The Clock', 2],
#  ['The Betrayal', 2],
#  ['The Gift', 2],
#  ['The Blair Witch Project', 2],
#  ['Blood: The Last Vampire', 2],
#  ['Smoke', 2],
#  ["The Razor's Edge", 2],
#  ['The Cameraman', 2],
#  ['Our Hospitality', 2],
#  ['College', 2],
#  ['Three Ages', 2],
#  ['Cops', 2],
#  ['The Playhouse', 2],
#  ['The Boat', 2],
#  ['The Haunted House', 2],
#  ['The Postman Always Rings Twice', 2],
#  ["A Bug's Life", 2],
#  ['Miracle on 34th Street', 2],
#  ['Dawn of the Dead', 2],
#  ['The Crazies', 2],
#  ['Night of the Living Dead', 2],
#  ['Stranger Things', 2],
#  ["Ocean's Eleven", 2],
#  ['The SpongeBob SquarePants Movie', 2],
#  ['Indie Game: The Movie', 2],
#  ['Lockout', 2],
#  ['Twilight', 2],
#  ['Lost in La Mancha', 2],
#  ['The Two Escobars', 2],
#  ['Crazy Love', 2],
#  ['Body', 2],
#  ['Bee Movie', 2],
#  ['Penguins of Madagascar', 2],
#  ['Shrek', 2],
#  ['The Road to Guantanamo', 2],
#  ['The Four', 2],
#  ["Salem's Lot", 2],
#  ['Inside Deep Throat', 2],
#  ['The Eyes of Tammy Faye', 2],
#  ['Wishful Drinking', 2],
#  ['Asterix and the Vikings', 2],
#  ['The Onion Movie', 2],
#  ['My Man Godfrey', 2],
#  ['Bad Company', 2],
#  ['The Cocoanuts', 2],
#  ['The Pirates! Band of Misfits', 2],
#  ['Dorm Daze', 2],
#  ['Halloween', 2],
#  ['Rush', 2],
#  ['Drift', 2],
#  ['Mind Game', 2],
#  ['The Girl Next Door', 2],
#  ['Of Mice and Men', 2],
#  ['Breathless', 2],
#  ['African Cats', 2],
#  ['Monkey Kingdom', 2],
#  ['The Adventures of Robin Hood', 2],
#  ['Sin City: A Dame to Kill For', 2],
#  ['The Transporter', 2],
#  ['Catfish', 2],
#  ['Nerve', 2],
#  ['Paranormal Activity 3', 2],
#  ['The Avengers', 2],
#  ['Jupiter Ascending', 2],
#  ['Speed Racer', 2],
#  ['The Matrix Revolutions', 2],
#  ['The Matrix Reloaded', 2],
#  ['The Matrix', 2],
#  ['Bound', 2],
#  ['And God Created Woman', 2],
#  ['Fright Night', 2],
#  ['Footloose', 2],
#  ['Jesus Camp', 2],
#  ['The Inbetweeners 2', 2],
#  ['The Poseidon Adventure', 2],
#  ['Deceiver', 2],
#  ['RoboCop', 2],
#  ['Bus 174', 2],
#  ['56 Up', 2],
#  ['49 Up', 2],
#  ['The Secret Life of Pets', 2],
#  ['Police Story', 2],
#  ['Crime Story', 2],
#  ['The Boxtrolls', 2],
#  ['The Alamo', 2],
#  ['The Rookie', 2],
#  ['Strictly Business', 2],
#  ['Zulu', 2],
#  ['Magic Trip', 2],
#  ['The Island', 2],
#  ['Tombstone', 2],
#  ['Teenage Mutant Ninja Turtles', 2],
#  ['Henry V', 2],
#  ['The Lords of Flatbush', 2],
#  ['American Reunion', 2],
#  ['Harold & Kumar Escape from Guantanamo Bay', 2],
#  ['The Biggest Fan', 2],
#  ['He Walked by Night', 2],
#  ['The Hobbit', 2],
#  ['The Last Unicorn', 2],
#  ['The Flight of Dragons', 2],
#  ['Sahara', 2],
#  ['Bolt', 2],
#  ['[REC]', 2],
#  ['Winnie the Pooh', 2],
#  ['Big Hero 6', 2],
#  ['The Book of Eli', 2],
#  ['From Hell', 2],
#  ['American Pimp', 2],
#  ['Menace II Society', 2],
#  ['Dead Presidents', 2],
#  ['The Princess and the Frog', 2],
#  ['Treasure Planet', 2],
#  ['The Little Mermaid', 2],
#  ['Aladdin', 2],
#  ['The Disappearance of Haruhi Suzumiya', 2],
#  ['Bangkok Dangerous', 2],
#  ['The Eye', 2],
#  ['Vampire Girl vs. Frankenstein Girl', 2],
#  ['Inside', 2],
#  ['The Wild Thornberrys Movie', 2],
#  ['Vampires Suck', 2],
#  ['Superfast!', 2],
#  ['Disaster Movie', 2],
#  ['Date Movie', 2],
#  ['Meet the Spartans', 2],
#  ['Epic Movie', 2],
#  ['Game of Death', 2],
#  ['Omen IV: The Awakening', 2],
#  ['Pygmalion', 2],
#  ['The Texas Chainsaw Massacre', 2],
#  ['Poltergeist', 2],
#  ['The Haunting', 2],
#  ['The Day the Earth Stood Still', 2],
#  ['Louis C.K.: Chewed Up', 2],
#  ['The Comancheros', 2],
#  ['Finding Nemo', 2],
#  ["Monty Python's The Meaning of Life", 2],
#  ['Monty Python and the Holy Grail', 2],
#  ['Safety Last!', 2],
#  ['Flipper', 2],
#  ['Balance', 2],
#  ['AVPR: Aliens vs. Predator - Requiem', 2],
#  ['Skyline', 2],
#  ['Dragon Ball Z: Bardock - The Father of Goku', 2],
#  ['Dragon Ball Z: The History of Trunks', 2],
#  ['Jonah: A VeggieTales Movie', 2],
#  ['Fierce Creatures', 2],
#  ['When a Stranger Calls', 2],
#  ['The Revenant', 2],
#  ['Oceans', 2],
#  ['Carriers', 2],
#  ['About a Boy', 2],
#  ['Down to Earth', 2],
#  ['American Pie', 2],
#  ['Gigantic', 2],
#  ['Microcosmos', 2],
#  ['Nighthawks', 2],
#  ['The Opposite Sex', 2],
#  ['The Dog', 2],
#  ["We're No Angels", 2],
#  ['Mildred Pierce', 2],
#  ['Steamboat Willie', 2],
#  ['The Tale of Despereaux', 2],
#  ['Proof', 2],
#  ['Running Scared', 2],
#  ['October Baby', 2],
#  ['Diabolique', 2],
#  ['The Toxic Avenger Part III: The Last Temptation of Toxie', 2],
#  ['The Toxic Avenger, Part II', 2],
#  ['The Toxic Avenger', 2],
#  ["Class of Nuke 'Em High", 2],
#  ['Antz', 2],
#  ['Corpse Bride', 2],
#  ['A Night at the Opera', 2],
#  ['The Invention of Lying', 2],
#  ['Father of the Bride', 2],
#  ['The Nutty Professor', 2],
#  ['22 Jump Street', 2],
#  ['21 Jump Street', 2],
#  ['The Lego Movie', 2],
#  ['Cloudy with a Chance of Meatballs', 2],
#  ['Return to Never Land', 2],
#  ['Twin Dragons', 2],
#  ['Despicable Me', 2],
#  ["Dr. Seuss' The Lorax", 2],
#  ['Despicable Me 2', 2],
#  ['Halloween 5: The Revenge of Michael Myers', 2],
#  ['Machete', 2],
#  ['Better Living Through Chemistry', 2],
#  ['Batman', 2],
#  ['Performance', 2],
#  ['Bon Voyage, Charlie Brown', 2],
#  ['Kickboxer', 2],
#  ['The Gallows', 2],
#  ['The Switch', 2],
#  ['Blades of Glory', 2],
#  ['Ice Age 4: Continental Drift', 2],
#  ['Horton Hears a Who!', 2],
#  ['The Art of the Steal', 2],
#  ['Robin Hood', 2],
#  ['Gladiator', 2],
#  ['Halfmoon', 2],
#  ['Minions', 2],
#  ['Aqua Teen Hunger Force Colon Movie Film for Theaters', 2],
#  ['Ruby Sparks', 2],
#  ['Little Miss Sunshine', 2],
#  ['Generation Kill', 2],
#  ['The Brandon Teena Story', 2],
#  ['The Killers', 2],
#  ['Return with Honor', 2],
#  ['Murderball', 2],
#  ['The Pagemaster', 2],
#  ["Cheech and Chong's Up in Smoke", 2],
#  ['American Splendor', 2],
#  ['The Nanny Diaries', 2],
#  ['Cropsey', 2],
#  ['Kaena: The Prophecy', 2],
#  ["Blind Spot: Hitler's Secretary", 2],
#  ['A Nightmare on Elm Street', 2],
#  ['Final Fantasy VII: Advent Children', 2],
#  ["Rock 'N' Roll High School", 2],
#  ['Himalaya', 2],
#  ['Life After Tomorrow', 2],
#  ['The Longest Yard', 2],
#  ['Neighbors', 2],
#  ['Superman II', 2],
#  ['The Omen', 2],
#  ['The D Train', 2],
#  ['Tig', 2],
#  ['The War Room', 2],
#  ['An Unreasonable Man', 2],
#  ['Alfie', 2],
#  ['Fury', 2],
#  ['Hush', 2],
#  ['The Wicker Man', 2],
#  ['Death at a Funeral', 2],
#  ['Possession', 2],
#  ["Fermat's Room", 2],
#  ['Cashback', 2],
#  ['Three of Hearts', 2],
#  ['Wings', 2],
#  ['Love Is a Many-Splendored Thing', 2],
#  ['Song of the South', 2],
#  ['Night and the City', 2],
#  ['Gunner Palace', 2],
#  ['Chocolat', 2],
#  ['Starry Eyes', 2],
#  ['Lord of the Flies', 2],
#  ['The King and I', 2],
#  ['Flesh Gordon', 2],
#  ['Robots', 2],
#  ['Ice Age', 2],
#  ['The Time Machine', 2],
#  ['Ice Age: Dawn of the Dinosaurs', 2],
#  ['Howl', 2],
#  ['Paragraph 175', 2],
#  ['Common Threads: Stories from the Quilt', 2],
#  ['Lovelace', 2],
#  ['The Celluloid Closet', 2],
#  ['Samsara', 2],
#  ['Cloudy with a Chance of Meatballs 2', 2],
#  ['Bleak House', 2],
#  ['American: The Bill Hicks Story', 2],
#  ['200 Motels', 2],
#  ["Empire of Dreams: The Story of the 'Star Wars' Trilogy", 2],
#  ['Family Guy Presents Stewie Griffin: The Untold Story', 2],
#  ['Escaflowne: The Movie', 2],
#  ['The Snows of Kilimanjaro', 2],
#  ['Atlantis: The Lost Empire', 2],
#  ['Hail, Caesar!', 2],
#  ['Burn After Reading', 2],
#  ['Inside Llewyn Davis', 2],
#  ['Intolerable Cruelty', 2],
#  ['No Country for Old Men', 2],
#  ['Barton Fink', 2],
#  ['A Serious Man', 2],
#  ["The Man Who Wasn't There", 2],
#  ['O Brother, Where Art Thou?', 2],
#  ['Blood Simple', 2],
#  ['The Big Lebowski', 2],
#  ['Raising Arizona', 2],
#  ["Miller's Crossing", 2],
#  ['Fargo', 2],
#  ['The Hudsucker Proxy', 2],
#  ['The Snowman', 2],
#  ['Super Mario Bros.', 2],
#  ['Drillbit Taylor', 1],
#  ['Without a Paddle', 1],
#  ['Mr. Deeds', 1],
#  ['Little Nicky', 1],
#  ['Heavyweights', 1],
#  ['Tremors', 1],
#  ['The Adventures of Pluto Nash', 1],
#  ['City Slickers', 1],
#  ['Heart and Souls', 1],
#  ['Speechless', 1],
#  ['Torch Song Trilogy', 1],
#  ['The Lake House', 1],
#  ['Valentín', 1],
#  ['They', 1],
#  ['Planes: Fire & Rescue', 1],
#  ['Like Mike', 1],
#  ['Aliens in the Attic', 1],
#  ['Drive Me Crazy', 1],
#  ['Dimples', 1],
#  ['Room Service', 1],
#  ['Stowaway', 1],
#  ['Sugar & Spice', 1],
#  ['Fortress', 1],
#  ['From Beyond', 1],
#  ['Re-Animator', 1],
#  ['Castle Freak', 1],
#  ['Along Came Polly', 1],
#  ['Safe Men', 1],
#  ['I Love You, Man', 1],
#  ['The Matador', 1],
#  ['The Hunting Party', 1],
#  ["I'll Sleep When I'm Dead", 1],
#  ['Morons From Outer Space', 1],
#  ['Flash Gordon', 1],
#  ['Croupier', 1],
#  ['Silk', 1],
#  ['The Red Violin', 1],
#  ['Thirty-Two Short Films About Glenn Gould', 1],
#  ['Larger Than Life', 1],
#  ['Brubaker', 1],
#  ['The Pope of Greenwich Village', 1],
#  ['Cool Hand Luke', 1],
#  ['The Harder They Come', 1],
#  ['Stonewall', 1],
#  ['Berserk', 1],
#  ['Wish Upon a Star', 1],
#  ['Kung Pow: Enter the Fist', 1],
#  ['Ace Ventura: When Nature Calls', 1],
#  ['Mental', 1],
#  ['Confessions of a Shopaholic', 1],
#  ["My Best Friend's Wedding", 1],
#  ["Muriel's Wedding", 1],
#  ['After School Special', 1],
#  ['The Sandlot', 1],
#  ['First Kid', 1],
#  ['For the Birds', 1],
#  ['Inequality for All', 1],
#  ['The Tuxedo', 1],
#  ['Pay It Forward', 1],
#  ['Deep Impact', 1],
#  ['The Peacemaker', 1],
#  ['Troll', 1],
#  ['Friday the 13th Part VII: The New Blood', 1],
#  ['Raggedy Man', 1],
#  ['Violets Are Blue', 1],
#  ['Presto', 1],
#  ['The Bigamist', 1],
#  ['The Hitch-Hiker', 1],
#  ['The land Before Time III: The Time of the Great Giving', 1],
#  ['Babylon 5: Thirdspace', 1],
#  ['My Name is Khan', 1],
#  ['Genghis Blues', 1],
#  ['Happy', 1],
#  ["National Lampoon's Lady Killers", 1],
#  ['Dreamer: Inspired by a True Story', 1],
#  ['The Rum Diary', 1],
#  ['How to Get Ahead in Advertising', 1],
#  ['Jennifer 8', 1],
#  ['Withnail & I', 1],
#  ['Land of Storms', 1],
#  ['Calendar Girls', 1],
#  ['Saving Grace', 1],
#  ['Made in Dagenham', 1],
#  ['A Lot Like Love', 1],
#  ['Gumby: The Movie', 1],
#  ['Find Me Guilty', 1],
#  ['Murder on the Orient Express', 1],
#  ["Long Day's Journey Into Night", 1],
#  ['Fail-Safe', 1],
#  ["Before the Devil Knows You're Dead", 1],
#  ['A Stranger Among Us', 1],
#  ['The Wiz', 1],
#  ['Equus', 1],
#  ['Q & A', 1],
#  ['Deathtrap', 1],
#  ['The Anderson Tapes', 1],
#  ['Family Business', 1],
#  ['Running on Empty', 1],
#  ['The Group', 1],
#  ['The Pawnbroker', 1],
#  ['Serpico', 1],
#  ...]

# %% [markdown]
# #### 6.The names of the directors and the title of the movies that they directed and in which they also played.

# %%
# %%cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH (m:Movie)<-[:DIRECTED]-(dir:Director),(actor:Actor)-[:ACTED_IN]->(m)
# WHERE actor.name= dir.name
# RETURN  dir.name AS Director  , COLLECT (m.title) AS Directed
# Out:
# 281 rows affected.
# [['Rick Moranis', ['Strange Brew']],
#  ['Jennifer Jason Leigh', ['The Anniversary Party']],
#  ['Steve Oedekerk', ['Kung Pow: Enter the Fist']],
#  ['Tony Jaa', ['Ong-Bak 2: The Beginning']],
#  ['Ralph Eggleston', ['For the Birds']],
#  ['Doug Sweetland', ['Presto']],
#  ['Ida Lupino', ['The Bigamist', 'On Dangerous Ground']],
#  ['Art Clokey', ['Gumby: The Movie']],
#  ['Paul Mazursky', ['Faithful']],
#  ['Y.K. Kim', ['Miami Connection']],
#  ['Chris Bell', ['Bigger, Stronger, Faster*']],
#  ['Keanu Reeves', ['Man of Tai Chi']],
#  ['Eric Schaeffer', ['If Lucy Fell']],
#  ['Lon Chaney', ['The Phantom of the Opera']],
#  ['Martin Scorsese',
#   ['A Personal Journey with Martin Scorsese Through American Movies',
#    'A Letter to Elia']],
#  ['Robert Mitchum', ['The Night of the Hunter']],
#  ['Ki-duk Kim', ['Spring, Summer, Fall, Winter... and Spring']],
#  ['John Huston', ['Wise Blood']],
#  ['Bruce Kimmel', ['The First Nudie Musical']],
#  ['Denny Tedesco', ['The Wrecking Crew']],
#  ['Ken Shapiro', ['The Groove Tube']],
#  ['Hugh Laurie', ['Maybe Baby']],
#  ['Spike Lee',
#   ['Jungle Fever', "Mo' Better Blues", "She's Gotta Have It", 'Girl 6']],
#  ['Justin Lo', ['The Conrad Boys']],
#  ['Seth Rogen', ['The Interview', 'This Is the End']],
#  ['Rusty Cundieff', ['Sprung', 'Fear of a Black Hat']],
#  ['Alan Alda', ['Sweet Liberty', 'The Four Seasons', "Betsy's Wedding"]],
#  ['Albert Brooks',
#   ['Looking for Comedy in the Muslim World',
#    'Lost in America',
#    'Real Life',
#    'Defending Your Life',
#    'The Muse',
#    'Mother']],
#  ['Woody Allen',
#   ['Broadway Danny Rose',
#    'Zelig',
#    "A Midsummer Night's Sex Comedy",
#    'Husbands and Wives',
#    'The Curse of the Jade Scorpion',
#    'New York Stories',
#    'Shadows and Fog',
#    'Love and Death',
#    'Everything You Always Wanted to Know About Sex * But Were Afraid to Ask',
#    'Small Time Crooks',
#    'Stardust Memories',
#    'Take the Money and Run',
#    'Manhattan',
#    'Annie Hall',
#    'Bananas',
#    'Sleeper',
#    'Manhattan Murder Mystery']],
#  ['Edward Norton', ['Keeping the Faith']],
#  ['Akiva Schaffer', ['Popstar: Never Stop Never Stopping']],
#  ['Don Cheadle', ['Miles Ahead']],
#  ['Lee Fulkerson', ['Forks Over Knives']],
#  ['Paul Wegener', ['The Golem']],
#  ['Jonathan Caouette', ['Tarnation']],
#  ['Tom Laughlin', ['Billy Jack']],
#  ['Bill Cosby', ['Bill Cosby, Himself']],
#  ['Joseph Gordon-Levitt', ['Don Jon']],
#  ['Ari Folman', ['Waltz with Bashir']],
#  ['Jonathan Frakes', ['Star Trek: Insurrection', 'Star Trek: First Contact']],
#  ['Lake Bell', ['In a World...']],
#  ['Patrick Brice', ['Creep']],
#  ['Mario Van Peebles', ['Baadasssss!']],
#  ['Mel Brooks',
#   ['High Anxiety',
#    'Life Stinks',
#    'Spaceballs',
#    'History of the World: Part I']],
#  ['John Cameron Mitchell', ['Hedwig and the Angry Inch']],
#  ['Joe Lia', ['FAQs']],
#  ['Sook-Yin Lee', ['Toronto Stories']],
#  ['Bruce Brown', ['The Endless Summer', 'On Any Sunday']],
#  ['Stephen Merchant', ['Hello Ladies: The Movie']],
#  ['Takeshi Kitano',
#   ['Sonatine',
#    'The Blind Swordsman: Zatoichi',
#    'Kikujiro',
#    'Brother',
#    'Fireworks']],
#  ['Jack Nicholson', ['The Terror', 'The Two Jakes']],
#  ['Mel Welles', ['The Little Shop of Horrors']],
#  ['Jim Mallon', ['Mystery Science Theater 3000: The Movie']],
#  ['Billy Crystal', ['Mr. Saturday Night', 'Forget Paris']],
#  ['Kurt Kuenne', ['Dear Zachary: A Letter to a Son About His Father']],
#  ['Bruce La Bruce', ['Hustler White']],
#  ['John Landis', ['Mr. Warmth: The Don Rickles Project']],
#  ['Roberto Benigni',
#   ['The Tiger and the Snow', 'Johnny Stecchino', 'Life Is Beautiful']],
#  ['Costa Botes', ['Forgotten Silver']],
#  ['Ross McElwee', ["Sherman's March"]],
#  ['Sylvester Stallone',
#   ['The Expendables',
#    'Rambo',
#    'Rocky IV',
#    'Rocky III',
#    'Rocky II',
#    'Rocky Balboa']],
#  ['Sammo Kam-Bo Hung', ['Project A', 'Kung Fu Cult Master']],
#  ['John Cleese', ['Fawlty Towers', 'A Fish Called Wanda']],
#  ['Robert Montgomery', ['They Were Expendable']],
#  ['Tom Noonan', ['The Wife', 'What Happened Was...']],
#  ['Danny DeVito',
#   ['Hoffa',
#    'Death to Smoochy',
#    'The War of the Roses',
#    'Throw Momma from the Train',
#    'Matilda']],
#  ['Samantha Futerman', ['Twinsters']],
#  ['Charles S. Dutton', ['Against the Ropes']],
#  ['Josh Fox', ['GasLand']],
#  ['Amir Bar-Lev', ['My Kid Could Paint That']],
#  ['Angus MacLane', ['BURN-E']],
#  ['Charles Chaplin',
#   ['The Immigrant',
#    'A King in New York',
#    'Monsieur Verdoux',
#    'The Gold Rush',
#    'Limelight',
#    'Modern Times',
#    'The Kid',
#    "A Dog's Life",
#    'The Great Dictator']],
#  ['Mathieu Kassovitz', ['Métisse']],
#  ['Michael Moore',
#   ['Bowling for Columbine', 'Sicko', 'Roger & Me', 'The Big One']],
#  ['John Paul Tremblay', ['Trailer Park Boys: Live at the North Pole']],
#  ['Chris Sanders', ['Lilo & Stitch']],
#  ['Mike Smith', ['Trailer Park Boys: Live at the North Pole']],
#  ['Warren Beatty', ['Reds', 'Heaven Can Wait', 'Dick Tracy']],
#  ['Joe Carnahan', ['Blood, Guts, Bullets and Octane']],
#  ['Agnès Jaoui', ['Look at Me', 'The Taste of Others']],
#  ['Malcolm St. Clair', ['The Goat']],
#  ["Shin'ya Tsukamoto", ['Tetsuo, the Iron Man', 'Tetsuo II: Body Hammer']],
#  ['Tim Robbins', ['Bob Roberts']],
#  ['Mark Achbar', ['Manufacturing Consent: Noam Chomsky and the Media']],
#  ['Edward Burns', ['Sidewalks of New York', "She's the One"]],
#  ['William Shatner', ['Star Trek V: The Final Frontier']],
#  ['Martin Lawrence', ['A Thin Line Between Love and Hate']],
#  ['Ben Stiller',
#   ['The Secret Life of Walter Mitty', 'Zoolander', 'Zoolander 2']],
#  ['Bobcat Goldthwait', ['Shakes the Clown']],
#  ['Yann Arthus-Bertrand', ['Home']],
#  ['Jason Bateman', ['Bad Words']],
#  ['Steve Buscemi', ['Trees Lounge']],
#  ['Kevin Heffernan', ["The Slammin' Salmon"]],
#  ['Chris Rock', ['Head of State', 'Top Five']],
#  ['Nacho Vigalondo', ['Timecrimes']],
#  ['Leonard Nimoy',
#   ['Star Trek IV: The Voyage Home', 'Star Trek III: The Search for Spock']],
#  ['Ben Affleck', ['Argo', 'The Town']],
#  ['Kevin Costner', ['Open Range', 'The Postman', 'Dances with Wolves']],
#  ['Julia Sweeney', ["God Said 'Ha!'"]],
#  ['Campbell Scott', ['Hamlet']],
#  ['Eleanor Coppola', ['Hearts of Darkness: A Filmmakers Apocalypse']],
#  ['Oliver Stone', ['Comandante']],
#  ['Michael Rosenbaum', ['Back in the Day']],
#  ['Julie Delpy', ['2 Days in New York']],
#  ['Jim Henson', ['The Great Muppet Caper', 'The Dark Crystal']],
#  ['Sally Potter', ['The Tango Lesson']],
#  ['Robert Ben Garant', ['Reno 911!: Miami']],
#  ['Kevin Spacey', ['Beyond the Sea']],
#  ['Yvan Attal', ['My Wife is an Actress']],
#  ['Morgan Spurlock', ['Freakonomics']],
#  ['Jemaine Clement', ['What We Do in the Shadows']],
#  ['Abel Ferrara', ['The Driller Killer']],
#  ['H.B. Halicki', ['Gone in 60 Seconds']],
#  ['Klaus Kinski', ['Vampire in Venice']],
#  ['Barbra Streisand',
#   ['Yentl', 'The Prince of Tides', 'The Mirror Has Two Faces']],
#  ['Orson Welles',
#   ['The Lady from Shanghai', 'The Stranger', 'Othello', 'Touch of Evil']],
#  ['Buster Keaton',
#   ['Steamboat Bill, Jr.',
#    'The Cameraman',
#    'Sherlock Jr.',
#    'The Navigator',
#    'Seven Chances',
#    'Three Ages',
#    'The General',
#    'Cops',
#    'The Paleface',
#    'The Playhouse',
#    'The Boat',
#    'The Goat',
#    'The Haunted House']],
#  ['John Maloof', ['Finding Vivian Maier']],
#  ['Peter Sellers', ['The Fiendish Plot of Dr. Fu Manchu']],
#  ['Sebastián Silva', ['Nasty Baby']],
#  ['Cyril Collard', ['Savage Nights']],
#  ['Mike Judge', ['Beavis and Butt-Head Do America']],
#  ['Gene Kelly',
#   ["That's Entertainment, Part II", 'On the Town', "Singin' in the Rain"]],
#  ['Bill Murray', ['Quick Change']],
#  ['Louie Psihoyos', ['The Cove']],
#  ['Nadine Labaki', ['Caramel']],
#  ['Mel Gibson', ['The Man Without a Face']],
#  ['Jodie Foster', ['The Beaver', 'Little Man Tate']],
#  ["Gavin O'Connor", ['Tumbleweeds']],
#  ['Hayao Miyazaki', ['Mei and the Kittenbus']],
#  ['Werner Herzog',
#   ['Lessons of Darkness',
#    'Encounters at the End of the World',
#    'Little Dieter Needs to Fly',
#    'Wings of Hope',
#    'Cave of Forgotten Dreams',
#    'My Best Fiend',
#    'Grizzly Man']],
#  ['Myles Berkowitz', ['20 Dates']],
#  ['Paul Gross', ['Hyena Road', 'Men with Brooms']],
#  ['Bruce Campbell', ['My Name Is Bruce']],
#  ['Henry Joost', ['Catfish']],
#  ['Bob Peterson', ['Up']],
#  ['Joel Edgerton', ['The Gift']],
#  ['Jackie Chan',
#   ['Who Am I?',
#    'Project A',
#    'Police Story',
#    'Crime Story',
#    'Dragon Lord',
#    'The Young Master',
#    'Armour of God',
#    'Armour of God II: Operation Condor']],
#  ['Alex Gibney', ['Taxi to the Dark Side']],
#  ['Burt Lancaster', ['The Kentuckian']],
#  ['Kenneth Branagh',
#   ['Jack Ryan: Shadow Recruit',
#    "Love's Labour's Lost",
#    "Peter's Friends",
#    'Dead Again',
#    'Henry V',
#    "Mary Shelley's Frankenstein"]],
#  ['Alex Kendrick', ['Courageous']],
#  ['Ben Steinbauer', ['Winnebago Man']],
#  ['Vilgot Sjöman', ['I Am Curious (Yellow)']],
#  ['Carma Hinton', ['The Gate of Heavenly Peace']],
#  ['Marlon Brando', ['One-Eyed Jacks']],
#  ['Adam Wingard', ['V/H/S']],
#  ['Marina de Van', ['In My Skin']],
#  ['Josh Radnor', ['Liberal Arts']],
#  ['Edward James Olmos', ['Battlestar Galactica: The Plan']],
#  ['Louis C.K.',
#   ['Louis C.K.: Live at The Comedy Store',
#    'Live at the Beacon Theater',
#    'Louis C.K.: Oh My God',
#    'Louis C.K.: Chewed Up',
#    'Louis C.K.: Hilarious']],
#  ['John Wayne', ['The Green Berets', 'The Comancheros', 'The Alamo']],
#  ['Terry Jones', ["Mr. Toad's Wild Ride", 'Erik the Viking']],
#  ['Hiroaki Aikawa', ['Life in a Day']],
#  ['Marcel Camus', ['Black Orpheus']],
#  ['Mike Nawrocki', ['Jonah: A VeggieTales Movie']],
#  ['Bill Paxton', ['Frailty']],
#  ['Stephen Chow', ['Kung Fu Hustle', 'Shaolin Soccer']],
#  ['Burt Reynolds', ["Sharky's Machine", 'The End']],
#  ['Mike Bonanno', ['The Yes Men Fix the World']],
#  ['Rosanna Arquette', ['Searching for Debra Winger']],
#  ['Walt Disney', ['Steamboat Willie']],
#  ['Michel Blanc', ['Dead Tired']],
#  ['Cheech Marin', ['Born in East L.A.']],
#  ['Eli Roth', ['Inglourious Basterds']],
#  ['Ricky Gervais',
#   ['Cemetery Junction',
#    'The Invention of Lying',
#    'Ricky Gervais Live 4: Science']],
#  ['Jerry Lewis', ['The Bellboy', 'The Nutty Professor']],
#  ['John Ireland', ['The Fast and the Furious']],
#  ['Michael Polish', ['Twin Falls Idaho']],
#  ['George Clooney', ['The Monuments Men', 'The Ides of March']],
#  ['Richard Pryor', ['Richard Pryor Here and Now']],
#  ['Bruce McDonald', ['Roadkill']],
#  ['Mike Birbiglia', ['Sleepwalk with Me']],
#  ['Nikita Mikhalkov', ['Burnt by the Sun']],
#  ['David Sandberg', ['Kung Fury']],
#  ['Christopher Scott Cherot', ['Hav Plenty']],
#  ['Thavisouk Phrasavath', ['The Betrayal']],
#  ['Ariel Schulman', ['Catfish']],
#  ['Nanni Moretti', ["The Son's Room"]],
#  ['Carl Sagan', ['Cosmos']],
#  ['Tommy Wiseau', ['The Room']],
#  ['Leslie Howard', ['Pygmalion']],
#  ['Vít Klusák', ['Czech Dream']],
#  ['Gene Wilder', ['The Woman in Red', 'Haunted Honeymoon']],
#  ['Rupert Murray', ['Unknown White Male']],
#  ['Joshua Zeman', ['Cropsey']],
#  ['Kevin Smith', ['Clerks II', 'Jay and Silent Bob Strike Back']],
#  ['Harold Lloyd', ['The Kid Brother']],
#  ['Ralph Arlyck', ['Following Sean']],
#  ['Ian Fitzgibbon', ['Death of a Superhero']],
#  ['Edward F. Cline', ['The Haunted House']],
#  ['Alan Cumming', ['The Anniversary Party']],
#  ['Mads Brügger', ['The Ambassador', 'The Red Chapel']],
#  ['Terry Gilliam',
#   ["Monty Python's The Meaning of Life", 'Monty Python and the Holy Grail']],
#  ['Nick Broomfield',
#   ['Aileen: Life and Death of a Serial Killer',
#    'Kurt & Courtney',
#    'Heidi Fleiss: Hollywood Madam']],
#  ['Alejandro Jodorowsky', ['The Holy Mountain', 'El Topo']],
#  ['Jon Favreau', ['Chef', 'Made']],
#  ['Emilio Estevez', ['Men at Work', 'Wisdom', 'Bobby']],
#  ['Lena Dunham', ['Tiny Furniture']],
#  ['Taika Waititi', ['Boy', 'What We Do in the Shadows']],
#  ['Jean-Claude Van Damme', ['The Quest']],
#  ['Robert De Niro', ['A Bronx Tale']],
#  ['Bud Luckey', ["Boundin'"]],
#  ['Banksy', ['Exit Through the Gift Shop']],
#  ['John Kahrs', ['Paperman']],
#  ['Bill Melendez', ['A Charlie Brown Christmas']],
#  ['Chi Muoi Lo', ['Catfish in Black Bean Sauce']],
#  ['Sergey Bodrov', ['Prisoner of the Mountains']],
#  ['Eddie Murphy', ['Harlem Nights']],
#  ['Bruce Lee', ['Way of the Dragon', 'Game of Death']],
#  ['Dan Aykroyd', ['Nothing But Trouble']],
#  ['Alex van Warmerdam', ['Waiter', 'Voyeur', 'Borgman', 'Schneider vs. Bax']],
#  ['Carl Reiner', ["Dead Men Don't Wear Plaid"]],
#  ['B.Z. Goldberg', ['Promises']],
#  ['Andy Bichlbaum', ['The Yes Men Fix the World']],
#  ['Barry W. Blaustein', ['Beyond the Mat']],
#  ['Andrew Jarecki', ['The Jinx: The Life and Deaths of Robert Durst']],
#  ['Timo Vuorensola', ['Star Wreck: In the Pirkinning']],
#  ['Denzel Washington', ['The Great Debaters', 'Antwone Fisher']],
#  ['Cem Yilmaz', ['A.R.O.G.', 'Pek Yakında']],
#  ['Jorma Taccone', ['Popstar: Never Stop Never Stopping']],
#  ['Don McKellar', ['Last Night']],
#  ['Amy S. Weber', ['A Girl Like Her']],
#  ['Rainer Werner Fassbinder', ['Fox and His Friends']],
#  ['Frank Oz', ['The Muppets Take Manhattan', 'The Dark Crystal']],
#  ['Marc Singer', ['Dark Days']],
#  ['Agnès Varda', ['The Gleaners & I']],
#  ['Eric Zala', ['Raiders of the Lost Ark: The Adaptation']],
#  ['Michael Apted', ['56 Up']],
#  ['Eugene Jarecki', ['The House I Live In']],
#  ['Russell Crowe', ['The Water Diviner']],
#  ['Miranda July', ['The Future', 'Me and You and Everyone We Know']],
#  ['Josiane Balasko', ['French Twist']],
#  ['Benoît Poelvoorde', ['Man Bites Dog']],
#  ['Phil Vischer', ['Jonah: A VeggieTales Movie']],
#  ['Chia-Liang Liu', ['Legendary Weapons of China']],
#  ['Shane Carruth', ['Primer', 'Upstream Color']],
#  ['Robert Redford',
#   ['Lions For Lambs', 'The Horse Whisperer', 'The Company You Keep']],
#  ['Rob Reiner', ['Alex and Emma', 'This Is Spinal Tap']],
#  ['Dave Thomas', ['Strange Brew']],
#  ['Jennifer Westfeldt', ['Friends with Kids']],
#  ['Peter Jackson', ['Forgotten Silver']],
#  ['Federico Fellini', ['The Clowns']],
#  ['Harold P. Warren', ['Manos: The Hands of Fate']],
#  ['Dave Willis', ['Aqua Teen Hunger Force Colon Movie Film for Theaters']],
#  ['Kiefer Sutherland', ['Truth or Consequences, N.M.']],
#  ['François Truffaut', ['The Wild Child']],
#  ['Robert Townsend', ['The Meteor Man', 'Hollywood Shuffle']],
#  ['Seth MacFarlane', ['Ted', 'A Million Ways to Die in the West', 'Ted 2']],
#  ['Zach Braff', ['Garden State']],
#  ['Yu Wang', ['Master of the Flying Guillotine']],
#  ['Ed Harris', ['Pollock']],
#  ['Tommy Lee Jones',
#   ['The Three Burials of Melquiades Estrada', 'The Sunset Limited']],
#  ['Natalie Portman', ['New York, I Love You']],
#  ['Stanley Tucci', ['The Impostors', 'Big Night']],
#  ['Trey Parker',
#   ['South Park: Imaginationland',
#    'Team America: World Police',
#    'South Park: Bigger, Longer and Uncut',
#    'Orgazmo']],
#  ['Barbara Sonneborn', ['Regret to Inform']],
#  ['Emmanuel Mouret', ['Shall We Kiss?']],
#  ['Jacques Perrin', ['Oceans', 'Winged Migration']],
#  ['Tommy Chong',
#   ["Cheech & Chong's The Corsican Brothers",
#    "Cheech & Chong's Next Movie",
#    "Cheech & Chong's Nice Dreams",
#    "Cheech and Chong's Up in Smoke"]],
#  ['Tyler Perry',
#   ["Tyler Perry's Why Did I Get Married?", 'Madea Goes to Jail']],
#  ['Vincent Gallo', ['The Brown Bunny', "Buffalo '66"]],
#  ['Clint Eastwood',
#   ['Gran Torino',
#    'Million Dollar Baby',
#    'The Rookie',
#    'Honkytonk Man',
#    'Firefox',
#    'Blood Work',
#    'Sudden Impact',
#    'The Gauntlet',
#    'Play Misty for Me',
#    'Bronco Billy',
#    'Space Cowboys',
#    'The Outlaw Josey Wales',
#    'High Plains Drifter',
#    'True Crime',
#    'Heartbreak Ridge',
#    'Pale Rider',
#    'Absolute Power',
#    'Unforgiven',
#    'A Perfect World',
#    'The Bridges of Madison County']],
#  ['Richard Linklater', ['Slacker']],
#  ['Barbara Brancaccio', ['Cropsey']],
#  ['Paul Bartel', ['Eating Raoul']],
#  ['Gary Sinise', ['Of Mice and Men']],
#  ['David Byrne', ['True Stories']],
#  ['Dennis Hopper', ['Easy Rider']],
#  ['Billy Bob Thornton', ['Sling Blade']],
#  ['Keenen Ivory Wayans',
#   ["I'm Gonna Git You Sucka", 'A Low Down Dirty Shame']],
#  ['Jacques Tati', ['Play Time', 'M. Hulot’s Holiday']],
#  ['Yahoo Serious', ['Young Einstein']],
#  ['Steve James', ['Stevie']],
#  ['Tom Green', ['Freddy Got Fingered']],
#  ['Roman Polanski', ['The Tenant']],
#  ['Donal Lardner Ward', ['The Suburbans']],
#  ['Anthony Perkins', ['Psycho III']],
#  ['Robb Wells', ['Trailer Park Boys: Live at the North Pole']],
#  ['Tom Hanks', ['Larry Crowne']],
#  ['Diane Keaton', ['Hanging Up']]]

# %% [markdown]
# #### 7. The genres of the movies in which Tom Hanks played.

# %%
# %%cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH  (tom:Actor{name:'Tom Hanks'})-[:ACTED_IN]->(m:Movie)-[:HAS_GENRE]-(gen:Genre)
# RETURN DISTINCT gen.name AS TomHanskGenre
# Out:
# 15 rows affected.
# [['imax'],
#  ['sci-fi'],
#  ['drama'],
#  ['adventure'],
#  ['animation'],
#  ['children'],
#  ['comedy'],
#  ['fantasy'],
#  ['thriller'],
#  ['mystery'],
#  ['documentary'],
#  ['action'],
#  ['romance'],
#  ['war'],
#  ['crime']]

# %% [markdown]
# #### 8. The title and the rate of all the movies that the user number 3 rated. Sort by rate in decreasing order.

# %%
# %%cypher http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH  (user:User{id:3})-[r:RATED]->(m:Movie)
# RETURN m.title AS MovieTitle, r.rate AS Rate
# Out:
# 51 rows affected.
# [['The White Stripes Under Great White Northern Lights', 4.0],
#  ['The Indian in the Cupboard', 3.0],
#  ['Braveheart', 4.0],
#  ['Heavenly Creatures', 3.5],
#  ['Major Payne', 3.0],
#  ['Pulp Fiction', 4.5],
#  ['The Shawshank Redemption', 5.0],
#  ['The Flintstones', 2.5],
#  ['Forrest Gump', 5.0],
#  ['Speed', 2.5],
#  ["Schindler's List", 3.0],
#  ['Aladdin', 3.0],
#  ['Batman', 3.0],
#  ['The Silence of the Lambs', 3.0],
#  ['Beauty and the Beast', 2.0],
#  ['Twister', 3.5],
#  ['Trainspotting', 4.0],
#  ['Bound', 3.0],
#  ['The Princess Bride', 5.0],
#  ['Star Wars: Episode VI - Return of the Jedi', 3.0],
#  ['Harold and Maude', 4.0],
#  ['Fried Green Tomatoes', 3.0],
#  ['Young Guns', 4.0],
#  ['Men in Black', 3.5],
#  ['Titanic', 4.5],
#  ['Fear and Loathing in Las Vegas', 4.0],
#  ['Saving Private Ryan', 4.0],
#  ['Happiness', 4.0],
#  ['Pet Sematary', 3.0],
#  ['Big Daddy', 3.0],
#  ['Summer of Sam', 3.5],
#  ['Ghostbusters', 3.0],
#  ['The Sixth Sense', 3.5],
#  ['Stir of Echoes', 4.0],
#  ['American Beauty', 4.0],
#  ['Fight Club', 5.0],
#  ['Encino Man', 3.0],
#  ['Frequency', 4.0],
#  ['Requiem for a Dream', 5.0],
#  ['Spider-Man', 3.0],
#  ['Bowling for Columbine', 3.5],
#  ['Finding Nemo', 3.0],
#  ['The Lord of the Rings: The Return of the King', 2.5],
#  ['Eternal Sunshine of the Spotless Mind', 3.0],
#  ['Fahrenheit 9/11', 3.5],
#  ['Spider-Man 2', 3.0],
#  ['Daria: Is It Fall Yet?', 3.5],
#  ['V for Vendetta', 3.5],
#  ['Flags of Our Fathers', 4.5],
#  ['Letters from Iwo Jima', 4.5],
#  ['The Dark Knight', 3.0]]

# %% [markdown]
# #### 9. The five movies that obtained the best average rate among the movies that have been rated by at least 100 users.

# %%
# %%cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH (usr:User)-[:RATED]->(m:Movie)
# WITH m, count(*)  as cnt
# MATCH (m)<-[r:RATED]-(usr)
# WHERE cnt >= 100
# RETURN m.title, cnt, avg(r.rate) AS averagerte
# ORDER BY  averagerte  DESC
# LIMIT 5
# Out:
# 5 rows affected.
# [['The Godfather', 200, 4.4875],
#  ['The Shawshank Redemption', 311, 4.487138263665597],
#  ['The Godfather: Part II', 135, 4.385185185185182],
#  ['The Usual Suspects', 201, 4.370646766169154],
#  ["Schindler's List", 244, 4.303278688524591]]
